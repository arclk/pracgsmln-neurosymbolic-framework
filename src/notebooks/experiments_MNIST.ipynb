# %%
import copy
import time
import json
import numpy as np
import pandas as pd

from sklearn.metrics import f1_score, precision_score, recall_score, confusion_matrix, classification_report, cohen_kappa_score, accuracy_score

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
device = "cpu"
base_dir = ".."

# %% [markdown]
# # Load data

# %% [markdown]
# Laod all the variables used in the learning algorithm:
#
#
# *   **var_dict** is the dictionary of all the variables grounded from the MRF (2000 for the predicate Digit, 20000 for the predicate Number)
# *   **nn_inputs** contains the inputs of the neural networks
# *   **varidx2fidx** is a dictionary containing, for each variable, the indexes of the grounding of the formulas that the variable makes true
# *   **stat** is a dictionary containing, for each grounding of each formula, the num­ber of times that each value of the variable makes that grounding true
# *   **evidence_mask** is a masking array containing the truth value of the variables

# %%
var_dict = torch.load(base_dir + '/mnist/data_notebook/train/mnist_variables.pt')
nn_inputs = torch.load(base_dir + '/mnist/data_notebook/train/mnist_inputs.pt')
varidx2fidx = torch.load(base_dir + '/mnist/data_notebook/train/mnist_varidx2fidx.pt')
stat = torch.load(base_dir + '/mnist/data_notebook/train/mnist_stat.pt')
evidence_mask = torch.load(base_dir + '/mnist/data_notebook/train/mnist_evidence_mask.pt')

# %%
X_train, y_train = torch.load(base_dir + '/mnist/data_notebook/train/mnist_train.pt')
X_test, y_test = torch.load(base_dir + '/mnist/data_notebook/test/mnist_test.pt')

X_train = X_train.unsqueeze(dim=1).float()
X_test = X_test.unsqueeze(dim=1).float()

# %% [markdown]
# Load only the first 2000 samples for training

# %%
X_train, y_train = X_train[:2000], y_train[:2000]

# %%
nn_inputs = [X_train]
y_true = y_train

val_inputs = [X_test]
val_true = y_test

# %%
number_dict = {}

for i in range(2000, 22000):
    number_dict[i-2000] = var_dict[i]

# %% [markdown]
# # Network

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(1, 10, kernel_size=5)
        self.conv2 = nn.Conv2d(10, 20, kernel_size=5)
        self.conv2_drop = nn.Dropout2d()
        self.fc1 = nn.Linear(320, 50)
        self.fc2 = nn.Linear(50, 10)

    def forward(self, x):
        x = F.relu(F.max_pool2d(self.conv1(x), 2))
        x = F.relu(F.max_pool2d(self.conv2_drop(self.conv2(x)), 2))
        x = x.view(-1, 320)
        x = F.relu(self.fc1(x))
        x = F.dropout(x, training=self.training)
        x = self.fc2(x)
        return x

# %% [markdown]
# # Training

# %%
def var_pl(varidx, wt):
    '''
    Computes the pseudo-likelihoods for the given variable under weights w. 
    '''
    values = 2
    var = var_dict[varidx]
    name, wt_idx1, wt_idx2, wt_idx3 = var

    if name == 'Digit':
        return torch.tensor([0, 1], dtype=torch.float)
    
    gfs = varidx2fidx.get(varidx)
    if gfs is None: 
        # no list was saved, so the truth of all formulas is unaffected by the variable's value
        # uniform distribution applies
        p = 1.0 / values
        return p * torch.ones(values, device=device)
    sums = torch.zeros(values, device=device)
    for fidx, groundings in gfs.items():
        for gidx in groundings:
            for validx, n in enumerate(stat[fidx][gidx][varidx]):
                if ftype[fidx] == 'hard': 
                    # penalize the prob mass of every value violating a hard constraint
                    if n == 0: 
                        sums[validx] = sums[validx] - 1000 * wt[fidx][wt_idx1][wt_idx2]
                else:
                    sums[validx] = sums[validx] + n * wt[fidx][wt_idx1][wt_idx2]

    return sums

# %%
def compute_pls(wt):
    '''
    Computes the pseudo-likelihoods for all the variables based on the
    weights wt which constitutes the outputs of the neural networks
    '''
    pls = []
    pls.append(torch.zeros((20000,2), device=device))

    for varidx in number_dict:
        pls[0][varidx] = var_pl(varidx+2000, wt)
    
    return pls

# %%
def grad(w):
    '''
    Computes the gradient taking into consideration the pseudo-likelihoods
    '''
    pls = compute_pls(w)
    grad = torch.zeros(len(nnformulas), dtype=torch.float64, device=device)
    plsidx = 0
    for fidx, groundval in stat.items():
        if fidx > 1:
            break
        for gidx, varval in groundval.items():
            for varidx, counts in varval.items():
                var = var_dict[varidx]
                name, _, _, evidx = var
                g = counts[evidx]
                if name == 'Text':
                    continue
                if name == 'Number':
                    plsidx = 0
                    varidx -= 2000

                for i, val in enumerate(counts):
                    g -= val * pls[plsidx][varidx][i]
                grad[fidx] += g
    # self.grad_opt_norm = torchsqrt(float(fsum([x * x for x in grad])))
    return grad

# %%
def forward():
    '''
    Computes the forward step of the nural networks
    '''
    wt = []
    for fidx, nn in enumerate(nnformulas):
        wt.append(nn(nn_inputs[fidx]))

    return wt

# %%
def train(optimizer, criterion, grad_mod):
    '''
    Computes an epoch of the full training step
    '''
    for model in nnformulas:
        model.train()

    optimizer.zero_grad()
    preds = forward()
    loss = criterion[0](preds[0], y_true)

    loss.backward()
    if (grad_mod):
        gradient = grad(preds)
        for fidx, nn in enumerate(nnformulas):
            for par in nn.parameters():
                par.grad *= gradient[fidx]

    optimizer.step()
    return loss

# %%
def evaluate():
    '''
    Evaluate the model
    '''
    for model in nnformulas:
        model.eval()

    pred = []
    with torch.no_grad():
        for fidx, nn in enumerate(nnformulas):
            pred.append(nn(val_inputs[fidx]))
        
        y = pred[0]
        y_pred = y.argmax(dim=1)
        y_pred = y_pred.to('cpu')
        
        acc = accuracy_score(val_true, y_pred)

        return acc

# %%
def training_loop(epochs, optimizer, criterion, pretrain=None,
                   early_stopping=True, early_stopping_epochs=1000, verbose=False):
    '''
    Computes the training algorithm with all the epochs and evaluate the model
    after each training step. It is possible to pretrain the model for a number
    of epochs given by the pretrain param.
    '''
    start_train = time.time()
    best_val_acc = 0
    best_epoch = 0
    epochs_no_improve = 0
    best_params = copy.deepcopy(nnformulas.state_dict())
    grad_mod = False

    for epoch in range(epochs):
        start_epoch = time.time()
        
        if (pretrain):
            if (epoch > pretrain):
                grad_mod = True
        else:
            grad_mod = True

        loss_train = train(optimizer, criterion, grad_mod)
        train_time = time.time()

        val_acc = evaluate()
        
        end_epoch = time.time()

        # Early stopping
        if val_acc > best_val_acc:
            epochs_no_improve = 0
            best_val_acc = val_acc
            best_params = copy.deepcopy(nnformulas.state_dict())
            best_epoch = epoch
        else: 
            epochs_no_improve += 1
        
        if early_stopping and epochs_no_improve == early_stopping_epochs:
            if verbose:
                print('Early stopping!' )
            break

        if verbose and (epoch+1)%1 == 0:
            print(f'Epoch: {epoch+1} '
                    f' Loss: Train = [{loss_train:.4f}] '
                    f' Acc: Val = [{val_acc:.4f}] '
                    f' Time one epoch (s): {end_epoch-start_epoch:.4f} ')

    end_train= time.time()
    print(f"Best epoch {best_epoch+1}, F1_macro: {best_val_acc:.4f}")
    print(f'Time for training: {end_train-start_train}')

    return best_val_acc, best_epoch, best_params

# %%
# Define the types of formulas (in this case only a neural formula)
ftype = ['nn']
nnformulas = torch.nn.ModuleList()
nnformulas.append(Net())

optimizer = torch.optim.Adam(nnformulas.parameters(), lr=0.001)
criterion = [nn.CrossEntropyLoss()]

# %%
best_valid_acc, best_epoch, best_params = training_loop(epochs=4000, optimizer=optimizer, criterion=criterion, 
                                                        pretrain=None, early_stopping=True, early_stopping_epochs=500, verbose=True)
# Out:
# Epoch: 1  Loss: Train = [20.1461]  Acc: Val = [0.1201]  Time one epoch (s): 6.1594
# Epoch: 2  Loss: Train = [13.3033]  Acc: Val = [0.1250]  Time one epoch (s): 6.5228
# Epoch: 3  Loss: Train = [9.0795]  Acc: Val = [0.1430]  Time one epoch (s): 6.6173
# Epoch: 4  Loss: Train = [6.0862]  Acc: Val = [0.1795]  Time one epoch (s): 6.8289
# Epoch: 5  Loss: Train = [4.4573]  Acc: Val = [0.2091]  Time one epoch (s): 6.8281
# Epoch: 6  Loss: Train = [3.6058]  Acc: Val = [0.2408]  Time one epoch (s): 6.8098
# Epoch: 7  Loss: Train = [2.9651]  Acc: Val = [0.2685]  Time one epoch (s): 6.7875
# Epoch: 8  Loss: Train = [2.6823]  Acc: Val = [0.2858]  Time one epoch (s): 6.7033
# Epoch: 9  Loss: Train = [2.5336]  Acc: Val = [0.2895]  Time one epoch (s): 6.8321
# Epoch: 10  Loss: Train = [2.3989]  Acc: Val = [0.2941]  Time one epoch (s): 6.7960
# Epoch: 11  Loss: Train = [2.3255]  Acc: Val = [0.2986]  Time one epoch (s): 6.8245
# Epoch: 12  Loss: Train = [2.2588]  Acc: Val = [0.3017]  Time one epoch (s): 6.5265
# Epoch: 13  Loss: Train = [2.2521]  Acc: Val = [0.3056]  Time one epoch (s): 6.4871
# Epoch: 14  Loss: Train = [2.2120]  Acc: Val = [0.3083]  Time one epoch (s): 6.4175
# Epoch: 15  Loss: Train = [2.1975]  Acc: Val = [0.3142]  Time one epoch (s): 6.3750
# Epoch: 16  Loss: Train = [2.1869]  Acc: Val = [0.3255]  Time one epoch (s): 6.4930
# Epoch: 17  Loss: Train = [2.1834]  Acc: Val = [0.3386]  Time one epoch (s): 6.5243
# Epoch: 18  Loss: Train = [2.1631]  Acc: Val = [0.3535]  Time one epoch (s): 6.5435
# Epoch: 19  Loss: Train = [2.1329]  Acc: Val = [0.3680]  Time one epoch (s): 6.5616
# Epoch: 20  Loss: Train = [2.1081]  Acc: Val = [0.3855]  Time one epoch (s): 6.5313
# Epoch: 21  Loss: Train = [2.0820]  Acc: Val = [0.4018]  Time one epoch (s): 6.5610
# Epoch: 22  Loss: Train = [2.0965]  Acc: Val = [0.4200]  Time one epoch (s): 6.5249
# Epoch: 23  Loss: Train = [2.0526]  Acc: Val = [0.4394]  Time one epoch (s): 6.5386
# Epoch: 24  Loss: Train = [2.0361]  Acc: Val = [0.4594]  Time one epoch (s): 6.4103
# Epoch: 25  Loss: Train = [2.0144]  Acc: Val = [0.4775]  Time one epoch (s): 6.5353
# Epoch: 26  Loss: Train = [1.9929]  Acc: Val = [0.4937]  Time one epoch (s): 6.4698
# Epoch: 27  Loss: Train = [1.9639]  Acc: Val = [0.5098]  Time one epoch (s): 6.5110
# Epoch: 28  Loss: Train = [1.9377]  Acc: Val = [0.5256]  Time one epoch (s): 6.5465
# Epoch: 29  Loss: Train = [1.9110]  Acc: Val = [0.5439]  Time one epoch (s): 6.4896
# Epoch: 30  Loss: Train = [1.8555]  Acc: Val = [0.5604]  Time one epoch (s): 6.4297
# Epoch: 31  Loss: Train = [1.8598]  Acc: Val = [0.5784]  Time one epoch (s): 6.4233
# Epoch: 32  Loss: Train = [1.8178]  Acc: Val = [0.5979]  Time one epoch (s): 6.7543
# Epoch: 33  Loss: Train = [1.7587]  Acc: Val = [0.6164]  Time one epoch (s): 6.8387
# Epoch: 34  Loss: Train = [1.7669]  Acc: Val = [0.6333]  Time one epoch (s): 6.5221
# Epoch: 35  Loss: Train = [1.7600]  Acc: Val = [0.6523]  Time one epoch (s): 6.4171
# Epoch: 36  Loss: Train = [1.6954]  Acc: Val = [0.6679]  Time one epoch (s): 6.4908
# Epoch: 37  Loss: Train = [1.6505]  Acc: Val = [0.6854]  Time one epoch (s): 6.5131
# Epoch: 38  Loss: Train = [1.6305]  Acc: Val = [0.7000]  Time one epoch (s): 6.5204
# Epoch: 39  Loss: Train = [1.5956]  Acc: Val = [0.7167]  Time one epoch (s): 6.5301
# Epoch: 40  Loss: Train = [1.5644]  Acc: Val = [0.7347]  Time one epoch (s): 6.5344
# Epoch: 41  Loss: Train = [1.5492]  Acc: Val = [0.7522]  Time one epoch (s): 6.5990
# Epoch: 42  Loss: Train = [1.5171]  Acc: Val = [0.7662]  Time one epoch (s): 6.5788
# Epoch: 43  Loss: Train = [1.4800]  Acc: Val = [0.7793]  Time one epoch (s): 6.5447
# Epoch: 44  Loss: Train = [1.4376]  Acc: Val = [0.7895]  Time one epoch (s): 6.5943
# Epoch: 45  Loss: Train = [1.3877]  Acc: Val = [0.8008]  Time one epoch (s): 6.5953
# Epoch: 46  Loss: Train = [1.3913]  Acc: Val = [0.8104]  Time one epoch (s): 6.5877
# Epoch: 47  Loss: Train = [1.3808]  Acc: Val = [0.8184]  Time one epoch (s): 6.6339
# Epoch: 48  Loss: Train = [1.3547]  Acc: Val = [0.8267]  Time one epoch (s): 6.7195
# Epoch: 49  Loss: Train = [1.2919]  Acc: Val = [0.8355]  Time one epoch (s): 6.5868
# Epoch: 50  Loss: Train = [1.3093]  Acc: Val = [0.8416]  Time one epoch (s): 6.5749
# Epoch: 51  Loss: Train = [1.2757]  Acc: Val = [0.8470]  Time one epoch (s): 6.5481
# Epoch: 52  Loss: Train = [1.2556]  Acc: Val = [0.8509]  Time one epoch (s): 6.5461
# Epoch: 53  Loss: Train = [1.2373]  Acc: Val = [0.8526]  Time one epoch (s): 6.5307
# Epoch: 54  Loss: Train = [1.2201]  Acc: Val = [0.8544]  Time one epoch (s): 6.4436
# Epoch: 55  Loss: Train = [1.1711]  Acc: Val = [0.8569]  Time one epoch (s): 6.5341
# Epoch: 56  Loss: Train = [1.1313]  Acc: Val = [0.8596]  Time one epoch (s): 6.5369
# Epoch: 57  Loss: Train = [1.0993]  Acc: Val = [0.8625]  Time one epoch (s): 6.4428
# Epoch: 58  Loss: Train = [1.0638]  Acc: Val = [0.8658]  Time one epoch (s): 6.5398
# Epoch: 59  Loss: Train = [1.0681]  Acc: Val = [0.8686]  Time one epoch (s): 6.5453
# Epoch: 60  Loss: Train = [1.0263]  Acc: Val = [0.8708]  Time one epoch (s): 6.5110
# Epoch: 61  Loss: Train = [1.0015]  Acc: Val = [0.8735]  Time one epoch (s): 6.4973
# Epoch: 62  Loss: Train = [0.9940]  Acc: Val = [0.8752]  Time one epoch (s): 6.4046
# Epoch: 63  Loss: Train = [1.0094]  Acc: Val = [0.8781]  Time one epoch (s): 6.4662
# Epoch: 64  Loss: Train = [0.9786]  Acc: Val = [0.8802]  Time one epoch (s): 6.4812
# Epoch: 65  Loss: Train = [0.9865]  Acc: Val = [0.8822]  Time one epoch (s): 6.3981
# Epoch: 66  Loss: Train = [0.9358]  Acc: Val = [0.8841]  Time one epoch (s): 6.5525
# Epoch: 67  Loss: Train = [0.9089]  Acc: Val = [0.8860]  Time one epoch (s): 6.5255
# Epoch: 68  Loss: Train = [0.9385]  Acc: Val = [0.8873]  Time one epoch (s): 6.4699
# Epoch: 69  Loss: Train = [0.9242]  Acc: Val = [0.8873]  Time one epoch (s): 6.5946
# Epoch: 70  Loss: Train = [0.8225]  Acc: Val = [0.8903]  Time one epoch (s): 6.7237
# Epoch: 71  Loss: Train = [0.9095]  Acc: Val = [0.8926]  Time one epoch (s): 6.7940
# Epoch: 72  Loss: Train = [0.8078]  Acc: Val = [0.8951]  Time one epoch (s): 6.5745
# Epoch: 73  Loss: Train = [0.8597]  Acc: Val = [0.8972]  Time one epoch (s): 6.6757
# Epoch: 74  Loss: Train = [0.8266]  Acc: Val = [0.8980]  Time one epoch (s): 6.7736
# Epoch: 75  Loss: Train = [0.7865]  Acc: Val = [0.8985]  Time one epoch (s): 6.6828
# Epoch: 76  Loss: Train = [0.8105]  Acc: Val = [0.8991]  Time one epoch (s): 6.5586
# Epoch: 77  Loss: Train = [0.7907]  Acc: Val = [0.9002]  Time one epoch (s): 6.7802
# Epoch: 78  Loss: Train = [0.7800]  Acc: Val = [0.9024]  Time one epoch (s): 6.7154
# Epoch: 79  Loss: Train = [0.7353]  Acc: Val = [0.9030]  Time one epoch (s): 6.4570
# Epoch: 80  Loss: Train = [0.7401]  Acc: Val = [0.9044]  Time one epoch (s): 6.4841
# Epoch: 81  Loss: Train = [0.7325]  Acc: Val = [0.9068]  Time one epoch (s): 6.4310
# Epoch: 82  Loss: Train = [0.7015]  Acc: Val = [0.9088]  Time one epoch (s): 6.4693
# Epoch: 83  Loss: Train = [0.7026]  Acc: Val = [0.9105]  Time one epoch (s): 6.5582
# Epoch: 84  Loss: Train = [0.6911]  Acc: Val = [0.9119]  Time one epoch (s): 6.5134
# Epoch: 85  Loss: Train = [0.7074]  Acc: Val = [0.9127]  Time one epoch (s): 6.4892
# Epoch: 86  Loss: Train = [0.6836]  Acc: Val = [0.9126]  Time one epoch (s): 6.4801
# Epoch: 87  Loss: Train = [0.6514]  Acc: Val = [0.9144]  Time one epoch (s): 6.4703
# Epoch: 88  Loss: Train = [0.6453]  Acc: Val = [0.9152]  Time one epoch (s): 6.4665
# Epoch: 89  Loss: Train = [0.6636]  Acc: Val = [0.9160]  Time one epoch (s): 6.4383
# Epoch: 90  Loss: Train = [0.6239]  Acc: Val = [0.9162]  Time one epoch (s): 6.4516
# Epoch: 91  Loss: Train = [0.6283]  Acc: Val = [0.9176]  Time one epoch (s): 6.4627
# Epoch: 92  Loss: Train = [0.6278]  Acc: Val = [0.9181]  Time one epoch (s): 6.4329
# Epoch: 93  Loss: Train = [0.5902]  Acc: Val = [0.9188]  Time one epoch (s): 6.5179
# Epoch: 94  Loss: Train = [0.5828]  Acc: Val = [0.9192]  Time one epoch (s): 6.4586
# Epoch: 95  Loss: Train = [0.6236]  Acc: Val = [0.9194]  Time one epoch (s): 6.4945
# Epoch: 96  Loss: Train = [0.5772]  Acc: Val = [0.9204]  Time one epoch (s): 6.4856
# Epoch: 97  Loss: Train = [0.6088]  Acc: Val = [0.9203]  Time one epoch (s): 6.5461
# Epoch: 98  Loss: Train = [0.5851]  Acc: Val = [0.9213]  Time one epoch (s): 6.4474
# Epoch: 99  Loss: Train = [0.5716]  Acc: Val = [0.9225]  Time one epoch (s): 6.5005
# Epoch: 100  Loss: Train = [0.5895]  Acc: Val = [0.9227]  Time one epoch (s): 6.5016
# Epoch: 101  Loss: Train = [0.5757]  Acc: Val = [0.9240]  Time one epoch (s): 6.4640
# Epoch: 102  Loss: Train = [0.5841]  Acc: Val = [0.9245]  Time one epoch (s): 6.4742
# Epoch: 103  Loss: Train = [0.5602]  Acc: Val = [0.9255]  Time one epoch (s): 6.4530
# Epoch: 104  Loss: Train = [0.5435]  Acc: Val = [0.9258]  Time one epoch (s): 6.4783
# Epoch: 105  Loss: Train = [0.5733]  Acc: Val = [0.9263]  Time one epoch (s): 6.4977
# Epoch: 106  Loss: Train = [0.5472]  Acc: Val = [0.9266]  Time one epoch (s): 6.5299
# Epoch: 107  Loss: Train = [0.4868]  Acc: Val = [0.9277]  Time one epoch (s): 6.4873
# Epoch: 108  Loss: Train = [0.5102]  Acc: Val = [0.9278]  Time one epoch (s): 6.4002
# Epoch: 109  Loss: Train = [0.5447]  Acc: Val = [0.9278]  Time one epoch (s): 6.5105
# Epoch: 110  Loss: Train = [0.4947]  Acc: Val = [0.9287]  Time one epoch (s): 6.4331
# Epoch: 111  Loss: Train = [0.5317]  Acc: Val = [0.9287]  Time one epoch (s): 6.4791
# Epoch: 112  Loss: Train = [0.5286]  Acc: Val = [0.9286]  Time one epoch (s): 6.4437
# Epoch: 113  Loss: Train = [0.5156]  Acc: Val = [0.9291]  Time one epoch (s): 6.4548
# Epoch: 114  Loss: Train = [0.5202]  Acc: Val = [0.9293]  Time one epoch (s): 6.4652
# Epoch: 115  Loss: Train = [0.4672]  Acc: Val = [0.9310]  Time one epoch (s): 6.5219
# Epoch: 116  Loss: Train = [0.4773]  Acc: Val = [0.9324]  Time one epoch (s): 6.4836
# Epoch: 117  Loss: Train = [0.4468]  Acc: Val = [0.9326]  Time one epoch (s): 6.4627
# Epoch: 118  Loss: Train = [0.4516]  Acc: Val = [0.9333]  Time one epoch (s): 6.4684
# Epoch: 119  Loss: Train = [0.4505]  Acc: Val = [0.9334]  Time one epoch (s): 6.5497
# Epoch: 120  Loss: Train = [0.4603]  Acc: Val = [0.9344]  Time one epoch (s): 6.5432
# Epoch: 121  Loss: Train = [0.4517]  Acc: Val = [0.9341]  Time one epoch (s): 6.5586
# Epoch: 122  Loss: Train = [0.4628]  Acc: Val = [0.9346]  Time one epoch (s): 6.4849
# Epoch: 123  Loss: Train = [0.4432]  Acc: Val = [0.9351]  Time one epoch (s): 6.4629
# Epoch: 124  Loss: Train = [0.4740]  Acc: Val = [0.9353]  Time one epoch (s): 6.5442
# Epoch: 125  Loss: Train = [0.4531]  Acc: Val = [0.9353]  Time one epoch (s): 6.5365
# Epoch: 126  Loss: Train = [0.4366]  Acc: Val = [0.9355]  Time one epoch (s): 6.4683
# Epoch: 127  Loss: Train = [0.4742]  Acc: Val = [0.9359]  Time one epoch (s): 6.5000
# Epoch: 128  Loss: Train = [0.4548]  Acc: Val = [0.9371]  Time one epoch (s): 6.4673
# Epoch: 129  Loss: Train = [0.4335]  Acc: Val = [0.9379]  Time one epoch (s): 6.5100
# Epoch: 130  Loss: Train = [0.4422]  Acc: Val = [0.9380]  Time one epoch (s): 6.5100
# Epoch: 131  Loss: Train = [0.4429]  Acc: Val = [0.9379]  Time one epoch (s): 6.4689
# Epoch: 132  Loss: Train = [0.4044]  Acc: Val = [0.9378]  Time one epoch (s): 6.4345
# Epoch: 133  Loss: Train = [0.4204]  Acc: Val = [0.9383]  Time one epoch (s): 6.4181
# Epoch: 134  Loss: Train = [0.3931]  Acc: Val = [0.9384]  Time one epoch (s): 6.5773
# Epoch: 135  Loss: Train = [0.4062]  Acc: Val = [0.9389]  Time one epoch (s): 6.4552
# Epoch: 136  Loss: Train = [0.4290]  Acc: Val = [0.9381]  Time one epoch (s): 6.4442
# Epoch: 137  Loss: Train = [0.3962]  Acc: Val = [0.9373]  Time one epoch (s): 6.5071
# Epoch: 138  Loss: Train = [0.4086]  Acc: Val = [0.9378]  Time one epoch (s): 6.4842
# Epoch: 139  Loss: Train = [0.4244]  Acc: Val = [0.9378]  Time one epoch (s): 6.5352
# Epoch: 140  Loss: Train = [0.3818]  Acc: Val = [0.9385]  Time one epoch (s): 6.4909
# Epoch: 141  Loss: Train = [0.3646]  Acc: Val = [0.9386]  Time one epoch (s): 6.4744
# Epoch: 142  Loss: Train = [0.3718]  Acc: Val = [0.9392]  Time one epoch (s): 6.5093
# Epoch: 143  Loss: Train = [0.4048]  Acc: Val = [0.9397]  Time one epoch (s): 6.4820
# Epoch: 144  Loss: Train = [0.3900]  Acc: Val = [0.9404]  Time one epoch (s): 6.5797
# Epoch: 145  Loss: Train = [0.3860]  Acc: Val = [0.9408]  Time one epoch (s): 6.5267
# Epoch: 146  Loss: Train = [0.3511]  Acc: Val = [0.9419]  Time one epoch (s): 6.5069
# Epoch: 147  Loss: Train = [0.4086]  Acc: Val = [0.9422]  Time one epoch (s): 6.5459
# Epoch: 148  Loss: Train = [0.3936]  Acc: Val = [0.9423]  Time one epoch (s): 6.5347
# Epoch: 149  Loss: Train = [0.3884]  Acc: Val = [0.9428]  Time one epoch (s): 6.6104
# Epoch: 150  Loss: Train = [0.3800]  Acc: Val = [0.9434]  Time one epoch (s): 6.5011
# Epoch: 151  Loss: Train = [0.3807]  Acc: Val = [0.9441]  Time one epoch (s): 6.5690
# Epoch: 152  Loss: Train = [0.3620]  Acc: Val = [0.9441]  Time one epoch (s): 6.4783
# Epoch: 153  Loss: Train = [0.3497]  Acc: Val = [0.9442]  Time one epoch (s): 6.4753
# Epoch: 154  Loss: Train = [0.3643]  Acc: Val = [0.9448]  Time one epoch (s): 6.5097
# Epoch: 155  Loss: Train = [0.3872]  Acc: Val = [0.9450]  Time one epoch (s): 6.5638
# Epoch: 156  Loss: Train = [0.3697]  Acc: Val = [0.9450]  Time one epoch (s): 6.4897
# Epoch: 157  Loss: Train = [0.3720]  Acc: Val = [0.9445]  Time one epoch (s): 6.4764
# Epoch: 158  Loss: Train = [0.3601]  Acc: Val = [0.9449]  Time one epoch (s): 6.4645
# Epoch: 159  Loss: Train = [0.3795]  Acc: Val = [0.9456]  Time one epoch (s): 6.4966
# Epoch: 160  Loss: Train = [0.3595]  Acc: Val = [0.9458]  Time one epoch (s): 6.5358
# Epoch: 161  Loss: Train = [0.3597]  Acc: Val = [0.9458]  Time one epoch (s): 6.5312
# Epoch: 162  Loss: Train = [0.3654]  Acc: Val = [0.9464]  Time one epoch (s): 6.5661
# Epoch: 163  Loss: Train = [0.3334]  Acc: Val = [0.9466]  Time one epoch (s): 6.4630
# Epoch: 164  Loss: Train = [0.3320]  Acc: Val = [0.9466]  Time one epoch (s): 6.4461
# Epoch: 165  Loss: Train = [0.3031]  Acc: Val = [0.9473]  Time one epoch (s): 6.5229
# Epoch: 166  Loss: Train = [0.3254]  Acc: Val = [0.9469]  Time one epoch (s): 6.4316
# Epoch: 167  Loss: Train = [0.3263]  Acc: Val = [0.9474]  Time one epoch (s): 6.4212
# Epoch: 168  Loss: Train = [0.3400]  Acc: Val = [0.9476]  Time one epoch (s): 6.5662
# Epoch: 169  Loss: Train = [0.3350]  Acc: Val = [0.9474]  Time one epoch (s): 6.5172
# Epoch: 170  Loss: Train = [0.3406]  Acc: Val = [0.9473]  Time one epoch (s): 6.5016
# Epoch: 171  Loss: Train = [0.3281]  Acc: Val = [0.9476]  Time one epoch (s): 6.5302
# Epoch: 172  Loss: Train = [0.2996]  Acc: Val = [0.9480]  Time one epoch (s): 6.4476
# Epoch: 173  Loss: Train = [0.3006]  Acc: Val = [0.9483]  Time one epoch (s): 6.4746
# Epoch: 174  Loss: Train = [0.3196]  Acc: Val = [0.9486]  Time one epoch (s): 6.4867
# Epoch: 175  Loss: Train = [0.3379]  Acc: Val = [0.9489]  Time one epoch (s): 6.4539
# Epoch: 176  Loss: Train = [0.3206]  Acc: Val = [0.9491]  Time one epoch (s): 6.4301
# Epoch: 177  Loss: Train = [0.2979]  Acc: Val = [0.9490]  Time one epoch (s): 6.4485
# Epoch: 178  Loss: Train = [0.3113]  Acc: Val = [0.9493]  Time one epoch (s): 6.4692
# Epoch: 179  Loss: Train = [0.3028]  Acc: Val = [0.9493]  Time one epoch (s): 6.4141
# Epoch: 180  Loss: Train = [0.3321]  Acc: Val = [0.9492]  Time one epoch (s): 6.5459
# Epoch: 181  Loss: Train = [0.3069]  Acc: Val = [0.9492]  Time one epoch (s): 6.5255
# Epoch: 182  Loss: Train = [0.2890]  Acc: Val = [0.9491]  Time one epoch (s): 6.4860
# Epoch: 183  Loss: Train = [0.3368]  Acc: Val = [0.9497]  Time one epoch (s): 6.5163
# Epoch: 184  Loss: Train = [0.2962]  Acc: Val = [0.9492]  Time one epoch (s): 6.5244
# Epoch: 185  Loss: Train = [0.3174]  Acc: Val = [0.9496]  Time one epoch (s): 6.5654
# Epoch: 186  Loss: Train = [0.3144]  Acc: Val = [0.9497]  Time one epoch (s): 6.5649
# Epoch: 187  Loss: Train = [0.3022]  Acc: Val = [0.9500]  Time one epoch (s): 6.5746
# Epoch: 188  Loss: Train = [0.2866]  Acc: Val = [0.9493]  Time one epoch (s): 6.5018
# Epoch: 189  Loss: Train = [0.2722]  Acc: Val = [0.9494]  Time one epoch (s): 6.5485
# Epoch: 190  Loss: Train = [0.2858]  Acc: Val = [0.9496]  Time one epoch (s): 6.5118
# Epoch: 191  Loss: Train = [0.2920]  Acc: Val = [0.9497]  Time one epoch (s): 6.5373
# Epoch: 192  Loss: Train = [0.2678]  Acc: Val = [0.9504]  Time one epoch (s): 6.4865
# Epoch: 193  Loss: Train = [0.3037]  Acc: Val = [0.9501]  Time one epoch (s): 6.4495
# Epoch: 194  Loss: Train = [0.2759]  Acc: Val = [0.9501]  Time one epoch (s): 6.4666
# Epoch: 195  Loss: Train = [0.2918]  Acc: Val = [0.9499]  Time one epoch (s): 6.5568
# Epoch: 196  Loss: Train = [0.2838]  Acc: Val = [0.9500]  Time one epoch (s): 6.4725
# Epoch: 197  Loss: Train = [0.2554]  Acc: Val = [0.9500]  Time one epoch (s): 6.4489
# Epoch: 198  Loss: Train = [0.2900]  Acc: Val = [0.9504]  Time one epoch (s): 6.4366
# Epoch: 199  Loss: Train = [0.2698]  Acc: Val = [0.9509]  Time one epoch (s): 6.5195
# Epoch: 200  Loss: Train = [0.2724]  Acc: Val = [0.9508]  Time one epoch (s): 6.5285
# Epoch: 201  Loss: Train = [0.2783]  Acc: Val = [0.9512]  Time one epoch (s): 6.5400
# Epoch: 202  Loss: Train = [0.2673]  Acc: Val = [0.9519]  Time one epoch (s): 6.5140
# Epoch: 203  Loss: Train = [0.2876]  Acc: Val = [0.9518]  Time one epoch (s): 6.5671
# Epoch: 204  Loss: Train = [0.2378]  Acc: Val = [0.9512]  Time one epoch (s): 6.4815
# Epoch: 205  Loss: Train = [0.2691]  Acc: Val = [0.9513]  Time one epoch (s): 6.6207
# Epoch: 206  Loss: Train = [0.2644]  Acc: Val = [0.9506]  Time one epoch (s): 6.5131
# Epoch: 207  Loss: Train = [0.2737]  Acc: Val = [0.9509]  Time one epoch (s): 6.4953
# Epoch: 208  Loss: Train = [0.2577]  Acc: Val = [0.9515]  Time one epoch (s): 6.5451
# Epoch: 209  Loss: Train = [0.2451]  Acc: Val = [0.9512]  Time one epoch (s): 6.5230
# Epoch: 210  Loss: Train = [0.2558]  Acc: Val = [0.9519]  Time one epoch (s): 6.4973
# Epoch: 211  Loss: Train = [0.2629]  Acc: Val = [0.9510]  Time one epoch (s): 6.5171
# Epoch: 212  Loss: Train = [0.2479]  Acc: Val = [0.9507]  Time one epoch (s): 6.4300
# Epoch: 213  Loss: Train = [0.2917]  Acc: Val = [0.9511]  Time one epoch (s): 6.5864
# Epoch: 214  Loss: Train = [0.2887]  Acc: Val = [0.9513]  Time one epoch (s): 6.5407
# Epoch: 215  Loss: Train = [0.2600]  Acc: Val = [0.9519]  Time one epoch (s): 6.5264
# Epoch: 216  Loss: Train = [0.2628]  Acc: Val = [0.9519]  Time one epoch (s): 6.4363
# Epoch: 217  Loss: Train = [0.2656]  Acc: Val = [0.9525]  Time one epoch (s): 6.5275
# Epoch: 218  Loss: Train = [0.2835]  Acc: Val = [0.9528]  Time one epoch (s): 6.4801
# Epoch: 219  Loss: Train = [0.2469]  Acc: Val = [0.9527]  Time one epoch (s): 6.5141
# Epoch: 220  Loss: Train = [0.2712]  Acc: Val = [0.9530]  Time one epoch (s): 6.4576
# Epoch: 221  Loss: Train = [0.2561]  Acc: Val = [0.9532]  Time one epoch (s): 6.5022
# Epoch: 222  Loss: Train = [0.2698]  Acc: Val = [0.9527]  Time one epoch (s): 6.4952
# Epoch: 223  Loss: Train = [0.2591]  Acc: Val = [0.9523]  Time one epoch (s): 6.4731
# Epoch: 224  Loss: Train = [0.2352]  Acc: Val = [0.9519]  Time one epoch (s): 6.4305
# Epoch: 225  Loss: Train = [0.2514]  Acc: Val = [0.9519]  Time one epoch (s): 6.4618
# Epoch: 226  Loss: Train = [0.2474]  Acc: Val = [0.9522]  Time one epoch (s): 6.4919
# Epoch: 227  Loss: Train = [0.2449]  Acc: Val = [0.9512]  Time one epoch (s): 6.5018
# Epoch: 228  Loss: Train = [0.2346]  Acc: Val = [0.9516]  Time one epoch (s): 6.4463
# Epoch: 229  Loss: Train = [0.2220]  Acc: Val = [0.9522]  Time one epoch (s): 6.4883
# Epoch: 230  Loss: Train = [0.2400]  Acc: Val = [0.9532]  Time one epoch (s): 6.4966
# Epoch: 231  Loss: Train = [0.2281]  Acc: Val = [0.9534]  Time one epoch (s): 6.5476
# Epoch: 232  Loss: Train = [0.2484]  Acc: Val = [0.9542]  Time one epoch (s): 6.5471
# Epoch: 233  Loss: Train = [0.2420]  Acc: Val = [0.9547]  Time one epoch (s): 6.4929
# Epoch: 234  Loss: Train = [0.2697]  Acc: Val = [0.9547]  Time one epoch (s): 6.4282
# Epoch: 235  Loss: Train = [0.2190]  Acc: Val = [0.9542]  Time one epoch (s): 6.4412
# Epoch: 236  Loss: Train = [0.2313]  Acc: Val = [0.9543]  Time one epoch (s): 6.4955
# Epoch: 237  Loss: Train = [0.2283]  Acc: Val = [0.9542]  Time one epoch (s): 6.5079
# Epoch: 238  Loss: Train = [0.2175]  Acc: Val = [0.9542]  Time one epoch (s): 6.4166
# Epoch: 239  Loss: Train = [0.2525]  Acc: Val = [0.9544]  Time one epoch (s): 6.5009
# Epoch: 240  Loss: Train = [0.2195]  Acc: Val = [0.9543]  Time one epoch (s): 6.5175
# Epoch: 241  Loss: Train = [0.2045]  Acc: Val = [0.9539]  Time one epoch (s): 6.4808
# Epoch: 242  Loss: Train = [0.2281]  Acc: Val = [0.9538]  Time one epoch (s): 6.5046
# Epoch: 243  Loss: Train = [0.2410]  Acc: Val = [0.9538]  Time one epoch (s): 6.5335
# Epoch: 244  Loss: Train = [0.2317]  Acc: Val = [0.9535]  Time one epoch (s): 6.5589
# Epoch: 245  Loss: Train = [0.2324]  Acc: Val = [0.9533]  Time one epoch (s): 6.4938
# Epoch: 246  Loss: Train = [0.2094]  Acc: Val = [0.9534]  Time one epoch (s): 6.4988
# Epoch: 247  Loss: Train = [0.2352]  Acc: Val = [0.9538]  Time one epoch (s): 6.5240
# Epoch: 248  Loss: Train = [0.2162]  Acc: Val = [0.9543]  Time one epoch (s): 6.4168
# Epoch: 249  Loss: Train = [0.2401]  Acc: Val = [0.9544]  Time one epoch (s): 6.4849
# Epoch: 250  Loss: Train = [0.2271]  Acc: Val = [0.9542]  Time one epoch (s): 6.4936
# Epoch: 251  Loss: Train = [0.2305]  Acc: Val = [0.9539]  Time one epoch (s): 6.5338
# Epoch: 252  Loss: Train = [0.2202]  Acc: Val = [0.9542]  Time one epoch (s): 6.5243
# Epoch: 253  Loss: Train = [0.2191]  Acc: Val = [0.9547]  Time one epoch (s): 6.4992
# Epoch: 254  Loss: Train = [0.2184]  Acc: Val = [0.9546]  Time one epoch (s): 6.5373
# Epoch: 255  Loss: Train = [0.2009]  Acc: Val = [0.9551]  Time one epoch (s): 6.5300
# Epoch: 256  Loss: Train = [0.2114]  Acc: Val = [0.9557]  Time one epoch (s): 6.4999
# Epoch: 257  Loss: Train = [0.2238]  Acc: Val = [0.9551]  Time one epoch (s): 6.5055
# Epoch: 258  Loss: Train = [0.2161]  Acc: Val = [0.9547]  Time one epoch (s): 6.5325
# Epoch: 259  Loss: Train = [0.1977]  Acc: Val = [0.9553]  Time one epoch (s): 6.5782
# Epoch: 260  Loss: Train = [0.2094]  Acc: Val = [0.9555]  Time one epoch (s): 6.5645
# Epoch: 261  Loss: Train = [0.1925]  Acc: Val = [0.9551]  Time one epoch (s): 6.5645
# Epoch: 262  Loss: Train = [0.1962]  Acc: Val = [0.9551]  Time one epoch (s): 6.5652
# Epoch: 263  Loss: Train = [0.2062]  Acc: Val = [0.9554]  Time one epoch (s): 6.5816
# Epoch: 264  Loss: Train = [0.2148]  Acc: Val = [0.9554]  Time one epoch (s): 6.5681
# Epoch: 265  Loss: Train = [0.2059]  Acc: Val = [0.9554]  Time one epoch (s): 6.5136
# Epoch: 266  Loss: Train = [0.2208]  Acc: Val = [0.9558]  Time one epoch (s): 6.5451
# Epoch: 267  Loss: Train = [0.1961]  Acc: Val = [0.9564]  Time one epoch (s): 6.5465
# Epoch: 268  Loss: Train = [0.1883]  Acc: Val = [0.9559]  Time one epoch (s): 6.5625
# Epoch: 269  Loss: Train = [0.1977]  Acc: Val = [0.9561]  Time one epoch (s): 6.5063
# Epoch: 270  Loss: Train = [0.2037]  Acc: Val = [0.9554]  Time one epoch (s): 6.4442
# Epoch: 271  Loss: Train = [0.1916]  Acc: Val = [0.9548]  Time one epoch (s): 6.4937
# Epoch: 272  Loss: Train = [0.1834]  Acc: Val = [0.9552]  Time one epoch (s): 6.5009
# Epoch: 273  Loss: Train = [0.1983]  Acc: Val = [0.9550]  Time one epoch (s): 6.4785
# Epoch: 274  Loss: Train = [0.1979]  Acc: Val = [0.9551]  Time one epoch (s): 6.5083
# Epoch: 275  Loss: Train = [0.2126]  Acc: Val = [0.9548]  Time one epoch (s): 6.4906
# Epoch: 276  Loss: Train = [0.1992]  Acc: Val = [0.9553]  Time one epoch (s): 6.5031
# Epoch: 277  Loss: Train = [0.1930]  Acc: Val = [0.9548]  Time one epoch (s): 6.5108
# Epoch: 278  Loss: Train = [0.1908]  Acc: Val = [0.9555]  Time one epoch (s): 6.4525
# Epoch: 279  Loss: Train = [0.1977]  Acc: Val = [0.9555]  Time one epoch (s): 6.5905
# Epoch: 280  Loss: Train = [0.2028]  Acc: Val = [0.9555]  Time one epoch (s): 6.4885
# Epoch: 281  Loss: Train = [0.1939]  Acc: Val = [0.9556]  Time one epoch (s): 6.5019
# Epoch: 282  Loss: Train = [0.2123]  Acc: Val = [0.9561]  Time one epoch (s): 6.4719
# Epoch: 283  Loss: Train = [0.1698]  Acc: Val = [0.9565]  Time one epoch (s): 6.4883
# Epoch: 284  Loss: Train = [0.1760]  Acc: Val = [0.9562]  Time one epoch (s): 6.4569
# Epoch: 285  Loss: Train = [0.1688]  Acc: Val = [0.9567]  Time one epoch (s): 6.4594
# Epoch: 286  Loss: Train = [0.1657]  Acc: Val = [0.9574]  Time one epoch (s): 6.5477
# Epoch: 287  Loss: Train = [0.2004]  Acc: Val = [0.9573]  Time one epoch (s): 6.5376
# Epoch: 288  Loss: Train = [0.1925]  Acc: Val = [0.9572]  Time one epoch (s): 6.5278
# Epoch: 289  Loss: Train = [0.1956]  Acc: Val = [0.9572]  Time one epoch (s): 6.5444
# Epoch: 290  Loss: Train = [0.1764]  Acc: Val = [0.9572]  Time one epoch (s): 6.4926
# Epoch: 291  Loss: Train = [0.2048]  Acc: Val = [0.9570]  Time one epoch (s): 6.5552
# Epoch: 292  Loss: Train = [0.1695]  Acc: Val = [0.9569]  Time one epoch (s): 6.4888
# Epoch: 293  Loss: Train = [0.1989]  Acc: Val = [0.9570]  Time one epoch (s): 6.4805
# Epoch: 294  Loss: Train = [0.1734]  Acc: Val = [0.9566]  Time one epoch (s): 6.5113
# Epoch: 295  Loss: Train = [0.1732]  Acc: Val = [0.9569]  Time one epoch (s): 6.5369
# Epoch: 296  Loss: Train = [0.1616]  Acc: Val = [0.9572]  Time one epoch (s): 6.4731
# Epoch: 297  Loss: Train = [0.1781]  Acc: Val = [0.9578]  Time one epoch (s): 6.5378
# Epoch: 298  Loss: Train = [0.1751]  Acc: Val = [0.9581]  Time one epoch (s): 6.4474
# Epoch: 299  Loss: Train = [0.2087]  Acc: Val = [0.9586]  Time one epoch (s): 6.4713
# Epoch: 300  Loss: Train = [0.2015]  Acc: Val = [0.9591]  Time one epoch (s): 6.5133
# Epoch: 301  Loss: Train = [0.1889]  Acc: Val = [0.9587]  Time one epoch (s): 6.4602
# Epoch: 302  Loss: Train = [0.1549]  Acc: Val = [0.9586]  Time one epoch (s): 6.5023
# Epoch: 303  Loss: Train = [0.1648]  Acc: Val = [0.9582]  Time one epoch (s): 6.5687
# Epoch: 304  Loss: Train = [0.1688]  Acc: Val = [0.9574]  Time one epoch (s): 6.4690
# Epoch: 305  Loss: Train = [0.1446]  Acc: Val = [0.9576]  Time one epoch (s): 6.5211
# Epoch: 306  Loss: Train = [0.1697]  Acc: Val = [0.9575]  Time one epoch (s): 6.5319
# Epoch: 307  Loss: Train = [0.1865]  Acc: Val = [0.9573]  Time one epoch (s): 6.5225
# Epoch: 308  Loss: Train = [0.1689]  Acc: Val = [0.9570]  Time one epoch (s): 6.5162
# Epoch: 309  Loss: Train = [0.1785]  Acc: Val = [0.9575]  Time one epoch (s): 6.5635
# Epoch: 310  Loss: Train = [0.1638]  Acc: Val = [0.9580]  Time one epoch (s): 6.5615
# Epoch: 311  Loss: Train = [0.1528]  Acc: Val = [0.9585]  Time one epoch (s): 6.5123
# Epoch: 312  Loss: Train = [0.1652]  Acc: Val = [0.9585]  Time one epoch (s): 6.5536
# Epoch: 313  Loss: Train = [0.1546]  Acc: Val = [0.9579]  Time one epoch (s): 6.5191
# Epoch: 314  Loss: Train = [0.1783]  Acc: Val = [0.9580]  Time one epoch (s): 6.5311
# Epoch: 315  Loss: Train = [0.1615]  Acc: Val = [0.9581]  Time one epoch (s): 6.5651
# Epoch: 316  Loss: Train = [0.2041]  Acc: Val = [0.9582]  Time one epoch (s): 6.4610
# Epoch: 317  Loss: Train = [0.1675]  Acc: Val = [0.9578]  Time one epoch (s): 6.5233
# Epoch: 318  Loss: Train = [0.1486]  Acc: Val = [0.9569]  Time one epoch (s): 6.4756
# Epoch: 319  Loss: Train = [0.1425]  Acc: Val = [0.9562]  Time one epoch (s): 6.4976
# Epoch: 320  Loss: Train = [0.1592]  Acc: Val = [0.9555]  Time one epoch (s): 6.4908
# Epoch: 321  Loss: Train = [0.1460]  Acc: Val = [0.9544]  Time one epoch (s): 6.4693
# Epoch: 322  Loss: Train = [0.1608]  Acc: Val = [0.9557]  Time one epoch (s): 6.4624
# Epoch: 323  Loss: Train = [0.1680]  Acc: Val = [0.9561]  Time one epoch (s): 6.5540
# Epoch: 324  Loss: Train = [0.1429]  Acc: Val = [0.9563]  Time one epoch (s): 6.4368
# Epoch: 325  Loss: Train = [0.1533]  Acc: Val = [0.9569]  Time one epoch (s): 6.5118
# Epoch: 326  Loss: Train = [0.1522]  Acc: Val = [0.9568]  Time one epoch (s): 6.5358
# Epoch: 327  Loss: Train = [0.1498]  Acc: Val = [0.9573]  Time one epoch (s): 6.5766
# Epoch: 328  Loss: Train = [0.1460]  Acc: Val = [0.9572]  Time one epoch (s): 6.5268
# Epoch: 329  Loss: Train = [0.1440]  Acc: Val = [0.9573]  Time one epoch (s): 6.4818
# Epoch: 330  Loss: Train = [0.1491]  Acc: Val = [0.9570]  Time one epoch (s): 6.4702
# Epoch: 331  Loss: Train = [0.1507]  Acc: Val = [0.9577]  Time one epoch (s): 6.5555
# Epoch: 332  Loss: Train = [0.1297]  Acc: Val = [0.9584]  Time one epoch (s): 6.5231
# Epoch: 333  Loss: Train = [0.1401]  Acc: Val = [0.9586]  Time one epoch (s): 6.5458
# Epoch: 334  Loss: Train = [0.1592]  Acc: Val = [0.9589]  Time one epoch (s): 6.6088
# Epoch: 335  Loss: Train = [0.1804]  Acc: Val = [0.9589]  Time one epoch (s): 6.5145
# Epoch: 336  Loss: Train = [0.1646]  Acc: Val = [0.9594]  Time one epoch (s): 6.5367
# Epoch: 337  Loss: Train = [0.1367]  Acc: Val = [0.9591]  Time one epoch (s): 6.5465
# Epoch: 338  Loss: Train = [0.1482]  Acc: Val = [0.9587]  Time one epoch (s): 6.5329
# Epoch: 339  Loss: Train = [0.1339]  Acc: Val = [0.9595]  Time one epoch (s): 6.5051
# Epoch: 340  Loss: Train = [0.1332]  Acc: Val = [0.9596]  Time one epoch (s): 6.4925
# Epoch: 341  Loss: Train = [0.1291]  Acc: Val = [0.9595]  Time one epoch (s): 6.4917
# Epoch: 342  Loss: Train = [0.1521]  Acc: Val = [0.9589]  Time one epoch (s): 6.5645
# Epoch: 343  Loss: Train = [0.1428]  Acc: Val = [0.9589]  Time one epoch (s): 6.4743
# Epoch: 344  Loss: Train = [0.1414]  Acc: Val = [0.9585]  Time one epoch (s): 6.5339
# Epoch: 345  Loss: Train = [0.1363]  Acc: Val = [0.9580]  Time one epoch (s): 6.4673
# Epoch: 346  Loss: Train = [0.1337]  Acc: Val = [0.9575]  Time one epoch (s): 6.4923
# Epoch: 347  Loss: Train = [0.1269]  Acc: Val = [0.9574]  Time one epoch (s): 6.5522
# Epoch: 348  Loss: Train = [0.1280]  Acc: Val = [0.9572]  Time one epoch (s): 6.5127
# Epoch: 349  Loss: Train = [0.1396]  Acc: Val = [0.9575]  Time one epoch (s): 6.5334
# Epoch: 350  Loss: Train = [0.1262]  Acc: Val = [0.9583]  Time one epoch (s): 6.5394
# Epoch: 351  Loss: Train = [0.1466]  Acc: Val = [0.9580]  Time one epoch (s): 6.5153
# Epoch: 352  Loss: Train = [0.1378]  Acc: Val = [0.9584]  Time one epoch (s): 6.5109
# Epoch: 353  Loss: Train = [0.1454]  Acc: Val = [0.9581]  Time one epoch (s): 6.5486
# Epoch: 354  Loss: Train = [0.1384]  Acc: Val = [0.9580]  Time one epoch (s): 6.5862
# Epoch: 355  Loss: Train = [0.1383]  Acc: Val = [0.9577]  Time one epoch (s): 6.5151
# Epoch: 356  Loss: Train = [0.1343]  Acc: Val = [0.9577]  Time one epoch (s): 6.5499
# Epoch: 357  Loss: Train = [0.1213]  Acc: Val = [0.9579]  Time one epoch (s): 6.5249
# Epoch: 358  Loss: Train = [0.1203]  Acc: Val = [0.9583]  Time one epoch (s): 6.5264
# Epoch: 359  Loss: Train = [0.1324]  Acc: Val = [0.9590]  Time one epoch (s): 6.5008
# Epoch: 360  Loss: Train = [0.1459]  Acc: Val = [0.9594]  Time one epoch (s): 6.6649
# Epoch: 361  Loss: Train = [0.1320]  Acc: Val = [0.9601]  Time one epoch (s): 6.6318
# Epoch: 362  Loss: Train = [0.1358]  Acc: Val = [0.9597]  Time one epoch (s): 6.4933
# Epoch: 363  Loss: Train = [0.1219]  Acc: Val = [0.9599]  Time one epoch (s): 6.5265
# Epoch: 364  Loss: Train = [0.1104]  Acc: Val = [0.9596]  Time one epoch (s): 6.4942
# Epoch: 365  Loss: Train = [0.1169]  Acc: Val = [0.9592]  Time one epoch (s): 6.6196
# Epoch: 366  Loss: Train = [0.1685]  Acc: Val = [0.9591]  Time one epoch (s): 6.6198
# Epoch: 367  Loss: Train = [0.1662]  Acc: Val = [0.9594]  Time one epoch (s): 6.6176
# Epoch: 368  Loss: Train = [0.1109]  Acc: Val = [0.9596]  Time one epoch (s): 6.6119
# Epoch: 369  Loss: Train = [0.1320]  Acc: Val = [0.9586]  Time one epoch (s): 6.6518
# Epoch: 370  Loss: Train = [0.1483]  Acc: Val = [0.9584]  Time one epoch (s): 6.5199
# Epoch: 371  Loss: Train = [0.1226]  Acc: Val = [0.9581]  Time one epoch (s): 6.5026
# Epoch: 372  Loss: Train = [0.1449]  Acc: Val = [0.9587]  Time one epoch (s): 6.5816
# Epoch: 373  Loss: Train = [0.1171]  Acc: Val = [0.9593]  Time one epoch (s): 6.6279
# Epoch: 374  Loss: Train = [0.1272]  Acc: Val = [0.9604]  Time one epoch (s): 6.5349
# Epoch: 375  Loss: Train = [0.1077]  Acc: Val = [0.9610]  Time one epoch (s): 6.6110
# Epoch: 376  Loss: Train = [0.1257]  Acc: Val = [0.9608]  Time one epoch (s): 6.5539
# Epoch: 377  Loss: Train = [0.1173]  Acc: Val = [0.9597]  Time one epoch (s): 6.5335
# Epoch: 378  Loss: Train = [0.1120]  Acc: Val = [0.9596]  Time one epoch (s): 6.5891
# Epoch: 379  Loss: Train = [0.1187]  Acc: Val = [0.9588]  Time one epoch (s): 6.5138
# Epoch: 380  Loss: Train = [0.1166]  Acc: Val = [0.9582]  Time one epoch (s): 6.5790
# Epoch: 381  Loss: Train = [0.1352]  Acc: Val = [0.9584]  Time one epoch (s): 6.5912
# Epoch: 382  Loss: Train = [0.1425]  Acc: Val = [0.9573]  Time one epoch (s): 6.5072
# Epoch: 383  Loss: Train = [0.1148]  Acc: Val = [0.9569]  Time one epoch (s): 6.5978
# Epoch: 384  Loss: Train = [0.1227]  Acc: Val = [0.9564]  Time one epoch (s): 6.5525
# Epoch: 385  Loss: Train = [0.1363]  Acc: Val = [0.9573]  Time one epoch (s): 6.5099
# Epoch: 386  Loss: Train = [0.1211]  Acc: Val = [0.9585]  Time one epoch (s): 6.5279
# Epoch: 387  Loss: Train = [0.1354]  Acc: Val = [0.9586]  Time one epoch (s): 6.5442
# Epoch: 388  Loss: Train = [0.1340]  Acc: Val = [0.9591]  Time one epoch (s): 6.5486
# Epoch: 389  Loss: Train = [0.1046]  Acc: Val = [0.9587]  Time one epoch (s): 6.5279
# Epoch: 390  Loss: Train = [0.1155]  Acc: Val = [0.9587]  Time one epoch (s): 6.5536
# Epoch: 391  Loss: Train = [0.1323]  Acc: Val = [0.9593]  Time one epoch (s): 6.5522
# Epoch: 392  Loss: Train = [0.1157]  Acc: Val = [0.9595]  Time one epoch (s): 6.5938
# Epoch: 393  Loss: Train = [0.1101]  Acc: Val = [0.9596]  Time one epoch (s): 6.5136
# Epoch: 394  Loss: Train = [0.1111]  Acc: Val = [0.9585]  Time one epoch (s): 6.4683
# Epoch: 395  Loss: Train = [0.1143]  Acc: Val = [0.9587]  Time one epoch (s): 6.6038
# Epoch: 396  Loss: Train = [0.1256]  Acc: Val = [0.9591]  Time one epoch (s): 6.5785
# Epoch: 397  Loss: Train = [0.1206]  Acc: Val = [0.9587]  Time one epoch (s): 6.5755
# Epoch: 398  Loss: Train = [0.1228]  Acc: Val = [0.9594]  Time one epoch (s): 6.5564
# Epoch: 399  Loss: Train = [0.1244]  Acc: Val = [0.9595]  Time one epoch (s): 6.5712
# Epoch: 400  Loss: Train = [0.1115]  Acc: Val = [0.9588]  Time one epoch (s): 6.5902
# Epoch: 401  Loss: Train = [0.1053]  Acc: Val = [0.9590]  Time one epoch (s): 6.5605
# Epoch: 402  Loss: Train = [0.1139]  Acc: Val = [0.9595]  Time one epoch (s): 6.5539
# Epoch: 403  Loss: Train = [0.1105]  Acc: Val = [0.9594]  Time one epoch (s): 6.5601
# Epoch: 404  Loss: Train = [0.1176]  Acc: Val = [0.9590]  Time one epoch (s): 6.5707
# Epoch: 405  Loss: Train = [0.1052]  Acc: Val = [0.9591]  Time one epoch (s): 6.4817
# Epoch: 406  Loss: Train = [0.1053]  Acc: Val = [0.9588]  Time one epoch (s): 6.5510
# Epoch: 407  Loss: Train = [0.1356]  Acc: Val = [0.9586]  Time one epoch (s): 6.5058
# Epoch: 408  Loss: Train = [0.1406]  Acc: Val = [0.9583]  Time one epoch (s): 6.5847
# Epoch: 409  Loss: Train = [0.1219]  Acc: Val = [0.9583]  Time one epoch (s): 6.5530
# Epoch: 410  Loss: Train = [0.1226]  Acc: Val = [0.9580]  Time one epoch (s): 6.5177
# Epoch: 411  Loss: Train = [0.1110]  Acc: Val = [0.9567]  Time one epoch (s): 6.6279
# Epoch: 412  Loss: Train = [0.1237]  Acc: Val = [0.9564]  Time one epoch (s): 6.5696
# Epoch: 413  Loss: Train = [0.1119]  Acc: Val = [0.9566]  Time one epoch (s): 6.5720
# Epoch: 414  Loss: Train = [0.1271]  Acc: Val = [0.9569]  Time one epoch (s): 6.5980
# Epoch: 415  Loss: Train = [0.1144]  Acc: Val = [0.9575]  Time one epoch (s): 6.5940
# Epoch: 416  Loss: Train = [0.1057]  Acc: Val = [0.9588]  Time one epoch (s): 6.5641
# Epoch: 417  Loss: Train = [0.1290]  Acc: Val = [0.9595]  Time one epoch (s): 6.5246
# Epoch: 418  Loss: Train = [0.1062]  Acc: Val = [0.9595]  Time one epoch (s): 6.4990
# Epoch: 419  Loss: Train = [0.1198]  Acc: Val = [0.9592]  Time one epoch (s): 6.5851
# Epoch: 420  Loss: Train = [0.1172]  Acc: Val = [0.9595]  Time one epoch (s): 6.5576
# Epoch: 421  Loss: Train = [0.1002]  Acc: Val = [0.9600]  Time one epoch (s): 6.5724
# Epoch: 422  Loss: Train = [0.1197]  Acc: Val = [0.9597]  Time one epoch (s): 6.5976
# Epoch: 423  Loss: Train = [0.1085]  Acc: Val = [0.9598]  Time one epoch (s): 6.6544
# Epoch: 424  Loss: Train = [0.1141]  Acc: Val = [0.9591]  Time one epoch (s): 6.5820
# Epoch: 425  Loss: Train = [0.0819]  Acc: Val = [0.9587]  Time one epoch (s): 6.5704
# Epoch: 426  Loss: Train = [0.1067]  Acc: Val = [0.9580]  Time one epoch (s): 6.5429
# Epoch: 427  Loss: Train = [0.0923]  Acc: Val = [0.9582]  Time one epoch (s): 6.5747
# Epoch: 428  Loss: Train = [0.0975]  Acc: Val = [0.9585]  Time one epoch (s): 6.5199
# Epoch: 429  Loss: Train = [0.1061]  Acc: Val = [0.9591]  Time one epoch (s): 6.4845
# Epoch: 430  Loss: Train = [0.1083]  Acc: Val = [0.9594]  Time one epoch (s): 6.4137
# Epoch: 431  Loss: Train = [0.1002]  Acc: Val = [0.9598]  Time one epoch (s): 6.4789
# Epoch: 432  Loss: Train = [0.0967]  Acc: Val = [0.9591]  Time one epoch (s): 6.4298
# Epoch: 433  Loss: Train = [0.1165]  Acc: Val = [0.9597]  Time one epoch (s): 6.4670
# Epoch: 434  Loss: Train = [0.1036]  Acc: Val = [0.9602]  Time one epoch (s): 6.4475
# Epoch: 435  Loss: Train = [0.1045]  Acc: Val = [0.9599]  Time one epoch (s): 6.4407
# Epoch: 436  Loss: Train = [0.0948]  Acc: Val = [0.9601]  Time one epoch (s): 6.4480
# Epoch: 437  Loss: Train = [0.0981]  Acc: Val = [0.9607]  Time one epoch (s): 6.4005
# Epoch: 438  Loss: Train = [0.1049]  Acc: Val = [0.9603]  Time one epoch (s): 6.4513
# Epoch: 439  Loss: Train = [0.0964]  Acc: Val = [0.9603]  Time one epoch (s): 6.4298
# Epoch: 440  Loss: Train = [0.1121]  Acc: Val = [0.9611]  Time one epoch (s): 6.4769
# Epoch: 441  Loss: Train = [0.1211]  Acc: Val = [0.9610]  Time one epoch (s): 6.3991
# Epoch: 442  Loss: Train = [0.1131]  Acc: Val = [0.9613]  Time one epoch (s): 6.4448
# Epoch: 443  Loss: Train = [0.0981]  Acc: Val = [0.9617]  Time one epoch (s): 6.4787
# Epoch: 444  Loss: Train = [0.1067]  Acc: Val = [0.9613]  Time one epoch (s): 6.4550
# Epoch: 445  Loss: Train = [0.1197]  Acc: Val = [0.9616]  Time one epoch (s): 6.3957
# Epoch: 446  Loss: Train = [0.1041]  Acc: Val = [0.9619]  Time one epoch (s): 6.3930
# Epoch: 447  Loss: Train = [0.0976]  Acc: Val = [0.9620]  Time one epoch (s): 6.4812
# Epoch: 448  Loss: Train = [0.1246]  Acc: Val = [0.9617]  Time one epoch (s): 6.5073
# Epoch: 449  Loss: Train = [0.1044]  Acc: Val = [0.9615]  Time one epoch (s): 6.5167
# Epoch: 450  Loss: Train = [0.0938]  Acc: Val = [0.9613]  Time one epoch (s): 6.5023
# Epoch: 451  Loss: Train = [0.0963]  Acc: Val = [0.9608]  Time one epoch (s): 6.4695
# Epoch: 452  Loss: Train = [0.1043]  Acc: Val = [0.9604]  Time one epoch (s): 6.4764
# Epoch: 453  Loss: Train = [0.0946]  Acc: Val = [0.9597]  Time one epoch (s): 6.4367
# Epoch: 454  Loss: Train = [0.0959]  Acc: Val = [0.9590]  Time one epoch (s): 6.4404
# Epoch: 455  Loss: Train = [0.1055]  Acc: Val = [0.9595]  Time one epoch (s): 6.4010
# Epoch: 456  Loss: Train = [0.0949]  Acc: Val = [0.9593]  Time one epoch (s): 6.4217
# Epoch: 457  Loss: Train = [0.0947]  Acc: Val = [0.9593]  Time one epoch (s): 6.3962
# Epoch: 458  Loss: Train = [0.1062]  Acc: Val = [0.9600]  Time one epoch (s): 6.3987
# Epoch: 459  Loss: Train = [0.0897]  Acc: Val = [0.9601]  Time one epoch (s): 6.3665
# Epoch: 460  Loss: Train = [0.0944]  Acc: Val = [0.9608]  Time one epoch (s): 6.4748
# Epoch: 461  Loss: Train = [0.0862]  Acc: Val = [0.9610]  Time one epoch (s): 6.3663
# Epoch: 462  Loss: Train = [0.1056]  Acc: Val = [0.9611]  Time one epoch (s): 6.3563
# Epoch: 463  Loss: Train = [0.1027]  Acc: Val = [0.9609]  Time one epoch (s): 6.4264
# Epoch: 464  Loss: Train = [0.1027]  Acc: Val = [0.9609]  Time one epoch (s): 6.4037
# Epoch: 465  Loss: Train = [0.0848]  Acc: Val = [0.9613]  Time one epoch (s): 6.3313
# Epoch: 466  Loss: Train = [0.1053]  Acc: Val = [0.9608]  Time one epoch (s): 6.3361
# Epoch: 467  Loss: Train = [0.0917]  Acc: Val = [0.9616]  Time one epoch (s): 6.2867
# Epoch: 468  Loss: Train = [0.1132]  Acc: Val = [0.9623]  Time one epoch (s): 6.3031
# Epoch: 469  Loss: Train = [0.1032]  Acc: Val = [0.9627]  Time one epoch (s): 6.4751
# Epoch: 470  Loss: Train = [0.0975]  Acc: Val = [0.9621]  Time one epoch (s): 6.4251
# Epoch: 471  Loss: Train = [0.0920]  Acc: Val = [0.9619]  Time one epoch (s): 6.3759
# Epoch: 472  Loss: Train = [0.0811]  Acc: Val = [0.9616]  Time one epoch (s): 6.7976
# Epoch: 473  Loss: Train = [0.0872]  Acc: Val = [0.9623]  Time one epoch (s): 6.4814
# Epoch: 474  Loss: Train = [0.0845]  Acc: Val = [0.9619]  Time one epoch (s): 6.5968
# Epoch: 475  Loss: Train = [0.1123]  Acc: Val = [0.9620]  Time one epoch (s): 6.5072
# Epoch: 476  Loss: Train = [0.1059]  Acc: Val = [0.9623]  Time one epoch (s): 6.5710
# Epoch: 477  Loss: Train = [0.0957]  Acc: Val = [0.9627]  Time one epoch (s): 6.5187
# Epoch: 478  Loss: Train = [0.1008]  Acc: Val = [0.9621]  Time one epoch (s): 6.5670
# Epoch: 479  Loss: Train = [0.1037]  Acc: Val = [0.9619]  Time one epoch (s): 6.4958
# Epoch: 480  Loss: Train = [0.0803]  Acc: Val = [0.9617]  Time one epoch (s): 6.5240
# Epoch: 481  Loss: Train = [0.1155]  Acc: Val = [0.9602]  Time one epoch (s): 6.5394
# Epoch: 482  Loss: Train = [0.0893]  Acc: Val = [0.9602]  Time one epoch (s): 6.4109
# Epoch: 483  Loss: Train = [0.1006]  Acc: Val = [0.9600]  Time one epoch (s): 6.5183
# Epoch: 484  Loss: Train = [0.1103]  Acc: Val = [0.9612]  Time one epoch (s): 6.5016
# Epoch: 485  Loss: Train = [0.0940]  Acc: Val = [0.9611]  Time one epoch (s): 6.4399
# Epoch: 486  Loss: Train = [0.0992]  Acc: Val = [0.9612]  Time one epoch (s): 6.4903
# Epoch: 487  Loss: Train = [0.0857]  Acc: Val = [0.9612]  Time one epoch (s): 6.4658
# Epoch: 488  Loss: Train = [0.0846]  Acc: Val = [0.9610]  Time one epoch (s): 6.4545
# Epoch: 489  Loss: Train = [0.0824]  Acc: Val = [0.9610]  Time one epoch (s): 6.4847
# Epoch: 490  Loss: Train = [0.0976]  Acc: Val = [0.9609]  Time one epoch (s): 6.5486
# Epoch: 491  Loss: Train = [0.0820]  Acc: Val = [0.9612]  Time one epoch (s): 6.4988
# Epoch: 492  Loss: Train = [0.0951]  Acc: Val = [0.9611]  Time one epoch (s): 6.4731
# Epoch: 493  Loss: Train = [0.0905]  Acc: Val = [0.9613]  Time one epoch (s): 6.3639
# Epoch: 494  Loss: Train = [0.0963]  Acc: Val = [0.9610]  Time one epoch (s): 6.5064
# Epoch: 495  Loss: Train = [0.0798]  Acc: Val = [0.9608]  Time one epoch (s): 6.5544
# Epoch: 496  Loss: Train = [0.0749]  Acc: Val = [0.9596]  Time one epoch (s): 6.4900
# Epoch: 497  Loss: Train = [0.0862]  Acc: Val = [0.9601]  Time one epoch (s): 6.5105
# Epoch: 498  Loss: Train = [0.0822]  Acc: Val = [0.9598]  Time one epoch (s): 6.4455
# Epoch: 499  Loss: Train = [0.0913]  Acc: Val = [0.9595]  Time one epoch (s): 6.5133
# Epoch: 500  Loss: Train = [0.0863]  Acc: Val = [0.9598]  Time one epoch (s): 6.4339
# Epoch: 501  Loss: Train = [0.0872]  Acc: Val = [0.9600]  Time one epoch (s): 6.3839
# Epoch: 502  Loss: Train = [0.1054]  Acc: Val = [0.9602]  Time one epoch (s): 6.3555
# Epoch: 503  Loss: Train = [0.0939]  Acc: Val = [0.9601]  Time one epoch (s): 6.4329
# Epoch: 504  Loss: Train = [0.1015]  Acc: Val = [0.9599]  Time one epoch (s): 6.3756
# Epoch: 505  Loss: Train = [0.1278]  Acc: Val = [0.9599]  Time one epoch (s): 6.2967
# Epoch: 506  Loss: Train = [0.0860]  Acc: Val = [0.9603]  Time one epoch (s): 6.3407
# Epoch: 507  Loss: Train = [0.0821]  Acc: Val = [0.9595]  Time one epoch (s): 6.2751
# Epoch: 508  Loss: Train = [0.0948]  Acc: Val = [0.9602]  Time one epoch (s): 6.3234
# Epoch: 509  Loss: Train = [0.0951]  Acc: Val = [0.9599]  Time one epoch (s): 6.2907
# Epoch: 510  Loss: Train = [0.0890]  Acc: Val = [0.9599]  Time one epoch (s): 6.3433
# Epoch: 511  Loss: Train = [0.0740]  Acc: Val = [0.9599]  Time one epoch (s): 6.3080
# Epoch: 512  Loss: Train = [0.0891]  Acc: Val = [0.9601]  Time one epoch (s): 6.2606
# Epoch: 513  Loss: Train = [0.0917]  Acc: Val = [0.9603]  Time one epoch (s): 6.2454
# Epoch: 514  Loss: Train = [0.0829]  Acc: Val = [0.9609]  Time one epoch (s): 6.2144
# Epoch: 515  Loss: Train = [0.0758]  Acc: Val = [0.9611]  Time one epoch (s): 6.3433
# Epoch: 516  Loss: Train = [0.0748]  Acc: Val = [0.9613]  Time one epoch (s): 6.3331
# Epoch: 517  Loss: Train = [0.0807]  Acc: Val = [0.9605]  Time one epoch (s): 6.4238
# Epoch: 518  Loss: Train = [0.0891]  Acc: Val = [0.9601]  Time one epoch (s): 6.4441
# Epoch: 519  Loss: Train = [0.0882]  Acc: Val = [0.9603]  Time one epoch (s): 6.4371
# Epoch: 520  Loss: Train = [0.0971]  Acc: Val = [0.9599]  Time one epoch (s): 6.3840
# Epoch: 521  Loss: Train = [0.0816]  Acc: Val = [0.9596]  Time one epoch (s): 6.4238
# Epoch: 522  Loss: Train = [0.0978]  Acc: Val = [0.9589]  Time one epoch (s): 6.4839
# Epoch: 523  Loss: Train = [0.0722]  Acc: Val = [0.9593]  Time one epoch (s): 6.5288
# Epoch: 524  Loss: Train = [0.0786]  Acc: Val = [0.9599]  Time one epoch (s): 6.4326
# Epoch: 525  Loss: Train = [0.0818]  Acc: Val = [0.9601]  Time one epoch (s): 6.4454
# Epoch: 526  Loss: Train = [0.1016]  Acc: Val = [0.9596]  Time one epoch (s): 6.3515
# Epoch: 527  Loss: Train = [0.0716]  Acc: Val = [0.9602]  Time one epoch (s): 6.4765
# Epoch: 528  Loss: Train = [0.0960]  Acc: Val = [0.9604]  Time one epoch (s): 6.3415
# Epoch: 529  Loss: Train = [0.0940]  Acc: Val = [0.9608]  Time one epoch (s): 6.3190
# Epoch: 530  Loss: Train = [0.0787]  Acc: Val = [0.9614]  Time one epoch (s): 6.2817
# Epoch: 531  Loss: Train = [0.0872]  Acc: Val = [0.9628]  Time one epoch (s): 6.3384
# Epoch: 532  Loss: Train = [0.0708]  Acc: Val = [0.9628]  Time one epoch (s): 6.2525
# Epoch: 533  Loss: Train = [0.0726]  Acc: Val = [0.9623]  Time one epoch (s): 6.2593
# Epoch: 534  Loss: Train = [0.0771]  Acc: Val = [0.9621]  Time one epoch (s): 6.2700
# Epoch: 535  Loss: Train = [0.0789]  Acc: Val = [0.9621]  Time one epoch (s): 6.3167
# Epoch: 536  Loss: Train = [0.0987]  Acc: Val = [0.9619]  Time one epoch (s): 6.3165
# Epoch: 537  Loss: Train = [0.0753]  Acc: Val = [0.9617]  Time one epoch (s): 6.3650
# Epoch: 538  Loss: Train = [0.0787]  Acc: Val = [0.9616]  Time one epoch (s): 6.2969
# Epoch: 539  Loss: Train = [0.0754]  Acc: Val = [0.9611]  Time one epoch (s): 6.4015
# Epoch: 540  Loss: Train = [0.0696]  Acc: Val = [0.9603]  Time one epoch (s): 6.3186
# Epoch: 541  Loss: Train = [0.0857]  Acc: Val = [0.9600]  Time one epoch (s): 6.3450
# Epoch: 542  Loss: Train = [0.0832]  Acc: Val = [0.9608]  Time one epoch (s): 6.3203
# Epoch: 543  Loss: Train = [0.0803]  Acc: Val = [0.9611]  Time one epoch (s): 6.2949
# Epoch: 544  Loss: Train = [0.0862]  Acc: Val = [0.9613]  Time one epoch (s): 6.3855
# Epoch: 545  Loss: Train = [0.0759]  Acc: Val = [0.9613]  Time one epoch (s): 6.3434
# Epoch: 546  Loss: Train = [0.0886]  Acc: Val = [0.9619]  Time one epoch (s): 6.3875
# Epoch: 547  Loss: Train = [0.0859]  Acc: Val = [0.9618]  Time one epoch (s): 6.4235
# Epoch: 548  Loss: Train = [0.0832]  Acc: Val = [0.9618]  Time one epoch (s): 6.3731
# Epoch: 549  Loss: Train = [0.0753]  Acc: Val = [0.9615]  Time one epoch (s): 6.3745
# Epoch: 550  Loss: Train = [0.0816]  Acc: Val = [0.9613]  Time one epoch (s): 6.4264
# Epoch: 551  Loss: Train = [0.0775]  Acc: Val = [0.9609]  Time one epoch (s): 6.4712
# Epoch: 552  Loss: Train = [0.0758]  Acc: Val = [0.9604]  Time one epoch (s): 6.4317
# Epoch: 553  Loss: Train = [0.0761]  Acc: Val = [0.9608]  Time one epoch (s): 6.4600
# Epoch: 554  Loss: Train = [0.0933]  Acc: Val = [0.9613]  Time one epoch (s): 6.4011
# Epoch: 555  Loss: Train = [0.0803]  Acc: Val = [0.9607]  Time one epoch (s): 6.4579
# Epoch: 556  Loss: Train = [0.0752]  Acc: Val = [0.9610]  Time one epoch (s): 6.5439
# Epoch: 557  Loss: Train = [0.0858]  Acc: Val = [0.9613]  Time one epoch (s): 6.4340
# Epoch: 558  Loss: Train = [0.0864]  Acc: Val = [0.9616]  Time one epoch (s): 6.4821
# Epoch: 559  Loss: Train = [0.0831]  Acc: Val = [0.9620]  Time one epoch (s): 6.4404
# Epoch: 560  Loss: Train = [0.0916]  Acc: Val = [0.9624]  Time one epoch (s): 6.4660
# Epoch: 561  Loss: Train = [0.0775]  Acc: Val = [0.9623]  Time one epoch (s): 6.4950
# Epoch: 562  Loss: Train = [0.0726]  Acc: Val = [0.9623]  Time one epoch (s): 6.5001
# Epoch: 563  Loss: Train = [0.0784]  Acc: Val = [0.9622]  Time one epoch (s): 6.4866
# Epoch: 564  Loss: Train = [0.0770]  Acc: Val = [0.9621]  Time one epoch (s): 6.4579
# Epoch: 565  Loss: Train = [0.0674]  Acc: Val = [0.9625]  Time one epoch (s): 6.4456
# ...
# Epoch: 923  Loss: Train = [0.0417]  Acc: Val = [0.9622]  Time one epoch (s): 6.4639
# Epoch: 924  Loss: Train = [0.0461]  Acc: Val = [0.9628]  Time one epoch (s): 6.4496
# Epoch: 925  Loss: Train = [0.0366]  Acc: Val = [0.9627]  Time one epoch (s): 6.5834
# Epoch: 926  Loss: Train = [0.0424]  Acc: Val = [0.9631]  Time one epoch (s): 6.4302
# Epoch: 927  Loss: Train = [0.0466]  Acc: Val = [0.9630]  Time one epoch (s): 6.4904
# Epoch: 928  Loss: Train = [0.0422]  Acc: Val = [0.9635]  Time one epoch (s): 6.5005
# Epoch: 929  Loss: Train = [0.0293]  Acc: Val = [0.9637]  Time one epoch (s): 6.4116
# Epoch: 930  Loss: Train = [0.0411]  Acc: Val = [0.9644]  Time one epoch (s): 6.4110
# Epoch: 931  Loss: Train = [0.0473]  Acc: Val = [0.9644]  Time one epoch (s): 6.3224
# Epoch: 932  Loss: Train = [0.0387]  Acc: Val = [0.9637]  Time one epoch (s): 6.3222
# Epoch: 933  Loss: Train = [0.0407]  Acc: Val = [0.9635]  Time one epoch (s): 6.3096
# Epoch: 934  Loss: Train = [0.0439]  Acc: Val = [0.9635]  Time one epoch (s): 6.3020
# Epoch: 935  Loss: Train = [0.0286]  Acc: Val = [0.9636]  Time one epoch (s): 6.3999
# Epoch: 936  Loss: Train = [0.0390]  Acc: Val = [0.9638]  Time one epoch (s): 6.4228
# Epoch: 937  Loss: Train = [0.0414]  Acc: Val = [0.9639]  Time one epoch (s): 6.3651
# Epoch: 938  Loss: Train = [0.0334]  Acc: Val = [0.9644]  Time one epoch (s): 6.4375
# Epoch: 939  Loss: Train = [0.0378]  Acc: Val = [0.9646]  Time one epoch (s): 6.5258
# Epoch: 940  Loss: Train = [0.0408]  Acc: Val = [0.9646]  Time one epoch (s): 6.4762
# Epoch: 941  Loss: Train = [0.0524]  Acc: Val = [0.9647]  Time one epoch (s): 6.4586
# Epoch: 942  Loss: Train = [0.0507]  Acc: Val = [0.9646]  Time one epoch (s): 6.4070
# Epoch: 943  Loss: Train = [0.0393]  Acc: Val = [0.9653]  Time one epoch (s): 6.5521
# Epoch: 944  Loss: Train = [0.0380]  Acc: Val = [0.9644]  Time one epoch (s): 6.5169
# Epoch: 945  Loss: Train = [0.0448]  Acc: Val = [0.9638]  Time one epoch (s): 6.4695
# Epoch: 946  Loss: Train = [0.0372]  Acc: Val = [0.9639]  Time one epoch (s): 6.4836
# Epoch: 947  Loss: Train = [0.0420]  Acc: Val = [0.9641]  Time one epoch (s): 6.5104
# Epoch: 948  Loss: Train = [0.0441]  Acc: Val = [0.9636]  Time one epoch (s): 6.4474
# Epoch: 949  Loss: Train = [0.0245]  Acc: Val = [0.9633]  Time one epoch (s): 6.4883
# Epoch: 950  Loss: Train = [0.0484]  Acc: Val = [0.9629]  Time one epoch (s): 6.4214
# Epoch: 951  Loss: Train = [0.0290]  Acc: Val = [0.9632]  Time one epoch (s): 6.5057
# Epoch: 952  Loss: Train = [0.0422]  Acc: Val = [0.9634]  Time one epoch (s): 6.5027
# Epoch: 953  Loss: Train = [0.0377]  Acc: Val = [0.9633]  Time one epoch (s): 6.4822
# Epoch: 954  Loss: Train = [0.0446]  Acc: Val = [0.9630]  Time one epoch (s): 6.4758
# Epoch: 955  Loss: Train = [0.0417]  Acc: Val = [0.9628]  Time one epoch (s): 6.4028
# Epoch: 956  Loss: Train = [0.0447]  Acc: Val = [0.9631]  Time one epoch (s): 6.3927
# Epoch: 957  Loss: Train = [0.0356]  Acc: Val = [0.9634]  Time one epoch (s): 6.4059
# Epoch: 958  Loss: Train = [0.0404]  Acc: Val = [0.9641]  Time one epoch (s): 6.4295
# Epoch: 959  Loss: Train = [0.0430]  Acc: Val = [0.9645]  Time one epoch (s): 6.3375
# Epoch: 960  Loss: Train = [0.0405]  Acc: Val = [0.9647]  Time one epoch (s): 6.2526
# Epoch: 961  Loss: Train = [0.0364]  Acc: Val = [0.9646]  Time one epoch (s): 6.1728
# Epoch: 962  Loss: Train = [0.0396]  Acc: Val = [0.9646]  Time one epoch (s): 6.2688
# Epoch: 963  Loss: Train = [0.0466]  Acc: Val = [0.9640]  Time one epoch (s): 6.4748
# Epoch: 964  Loss: Train = [0.0451]  Acc: Val = [0.9638]  Time one epoch (s): 6.2989
# Epoch: 965  Loss: Train = [0.0405]  Acc: Val = [0.9634]  Time one epoch (s): 6.3870
# Epoch: 966  Loss: Train = [0.0505]  Acc: Val = [0.9632]  Time one epoch (s): 6.5086
# Epoch: 967  Loss: Train = [0.0488]  Acc: Val = [0.9635]  Time one epoch (s): 6.6771
# Epoch: 968  Loss: Train = [0.0377]  Acc: Val = [0.9634]  Time one epoch (s): 6.5764
# Epoch: 969  Loss: Train = [0.0332]  Acc: Val = [0.9636]  Time one epoch (s): 6.5420
# Epoch: 970  Loss: Train = [0.0466]  Acc: Val = [0.9642]  Time one epoch (s): 6.5076
# Epoch: 971  Loss: Train = [0.0384]  Acc: Val = [0.9641]  Time one epoch (s): 6.5819
# Epoch: 972  Loss: Train = [0.0310]  Acc: Val = [0.9642]  Time one epoch (s): 6.6330
# Epoch: 973  Loss: Train = [0.0480]  Acc: Val = [0.9637]  Time one epoch (s): 6.5815
# Epoch: 974  Loss: Train = [0.0340]  Acc: Val = [0.9646]  Time one epoch (s): 6.6351
# Epoch: 975  Loss: Train = [0.0488]  Acc: Val = [0.9646]  Time one epoch (s): 6.5185
# Epoch: 976  Loss: Train = [0.0368]  Acc: Val = [0.9645]  Time one epoch (s): 6.5279
# Epoch: 977  Loss: Train = [0.0329]  Acc: Val = [0.9648]  Time one epoch (s): 6.4460
# Epoch: 978  Loss: Train = [0.0409]  Acc: Val = [0.9643]  Time one epoch (s): 6.4014
# Epoch: 979  Loss: Train = [0.0517]  Acc: Val = [0.9639]  Time one epoch (s): 6.4451
# Epoch: 980  Loss: Train = [0.0373]  Acc: Val = [0.9641]  Time one epoch (s): 6.4687
# Epoch: 981  Loss: Train = [0.0341]  Acc: Val = [0.9643]  Time one epoch (s): 6.4753
# Epoch: 982  Loss: Train = [0.0430]  Acc: Val = [0.9641]  Time one epoch (s): 6.5065
# Epoch: 983  Loss: Train = [0.0546]  Acc: Val = [0.9641]  Time one epoch (s): 6.5600
# Epoch: 984  Loss: Train = [0.0399]  Acc: Val = [0.9638]  Time one epoch (s): 6.4299
# Epoch: 985  Loss: Train = [0.0345]  Acc: Val = [0.9639]  Time one epoch (s): 6.4634
# Epoch: 986  Loss: Train = [0.0340]  Acc: Val = [0.9632]  Time one epoch (s): 6.4600
# Epoch: 987  Loss: Train = [0.0371]  Acc: Val = [0.9632]  Time one epoch (s): 6.4449
# Epoch: 988  Loss: Train = [0.0376]  Acc: Val = [0.9631]  Time one epoch (s): 6.4618
# Epoch: 989  Loss: Train = [0.0402]  Acc: Val = [0.9628]  Time one epoch (s): 6.5114
# Epoch: 990  Loss: Train = [0.0537]  Acc: Val = [0.9628]  Time one epoch (s): 6.4833
# Epoch: 991  Loss: Train = [0.0401]  Acc: Val = [0.9630]  Time one epoch (s): 6.3810
# Epoch: 992  Loss: Train = [0.0275]  Acc: Val = [0.9632]  Time one epoch (s): 6.3534
# Epoch: 993  Loss: Train = [0.0246]  Acc: Val = [0.9639]  Time one epoch (s): 6.3153
# Epoch: 994  Loss: Train = [0.0309]  Acc: Val = [0.9637]  Time one epoch (s): 6.3466
# Epoch: 995  Loss: Train = [0.0337]  Acc: Val = [0.9636]  Time one epoch (s): 6.3896
# Epoch: 996  Loss: Train = [0.0482]  Acc: Val = [0.9636]  Time one epoch (s): 6.3023
# Epoch: 997  Loss: Train = [0.0360]  Acc: Val = [0.9634]  Time one epoch (s): 6.3027
# Epoch: 998  Loss: Train = [0.0345]  Acc: Val = [0.9636]  Time one epoch (s): 6.3325
# Epoch: 999  Loss: Train = [0.0469]  Acc: Val = [0.9636]  Time one epoch (s): 6.3887
# Epoch: 1000  Loss: Train = [0.0441]  Acc: Val = [0.9634]  Time one epoch (s): 6.4119
# Epoch: 1001  Loss: Train = [0.0407]  Acc: Val = [0.9643]  Time one epoch (s): 6.4074
# Epoch: 1002  Loss: Train = [0.0354]  Acc: Val = [0.9642]  Time one epoch (s): 6.4679
# Epoch: 1003  Loss: Train = [0.0431]  Acc: Val = [0.9650]  Time one epoch (s): 6.3839
# Epoch: 1004  Loss: Train = [0.0529]  Acc: Val = [0.9645]  Time one epoch (s): 6.4307
# Epoch: 1005  Loss: Train = [0.0283]  Acc: Val = [0.9635]  Time one epoch (s): 6.4460
# Epoch: 1006  Loss: Train = [0.0450]  Acc: Val = [0.9631]  Time one epoch (s): 6.4776
# Epoch: 1007  Loss: Train = [0.0341]  Acc: Val = [0.9626]  Time one epoch (s): 6.4567
# Epoch: 1008  Loss: Train = [0.0336]  Acc: Val = [0.9627]  Time one epoch (s): 6.4250
# Epoch: 1009  Loss: Train = [0.0351]  Acc: Val = [0.9631]  Time one epoch (s): 6.4580
# Epoch: 1010  Loss: Train = [0.0287]  Acc: Val = [0.9633]  Time one epoch (s): 6.4279
# Epoch: 1011  Loss: Train = [0.0430]  Acc: Val = [0.9630]  Time one epoch (s): 6.4044
# Epoch: 1012  Loss: Train = [0.0465]  Acc: Val = [0.9629]  Time one epoch (s): 6.3762
# Epoch: 1013  Loss: Train = [0.0441]  Acc: Val = [0.9632]  Time one epoch (s): 6.4577
# Epoch: 1014  Loss: Train = [0.0389]  Acc: Val = [0.9630]  Time one epoch (s): 6.4897
# Epoch: 1015  Loss: Train = [0.0384]  Acc: Val = [0.9623]  Time one epoch (s): 6.4988
# Epoch: 1016  Loss: Train = [0.0272]  Acc: Val = [0.9631]  Time one epoch (s): 6.4239
# Epoch: 1017  Loss: Train = [0.0373]  Acc: Val = [0.9634]  Time one epoch (s): 6.4740
# Epoch: 1018  Loss: Train = [0.0425]  Acc: Val = [0.9639]  Time one epoch (s): 6.4802
# Epoch: 1019  Loss: Train = [0.0483]  Acc: Val = [0.9637]  Time one epoch (s): 6.5121
# Epoch: 1020  Loss: Train = [0.0337]  Acc: Val = [0.9633]  Time one epoch (s): 6.4559
# Epoch: 1021  Loss: Train = [0.0352]  Acc: Val = [0.9634]  Time one epoch (s): 6.4063
# Epoch: 1022  Loss: Train = [0.0429]  Acc: Val = [0.9633]  Time one epoch (s): 6.4190
# Epoch: 1023  Loss: Train = [0.0422]  Acc: Val = [0.9633]  Time one epoch (s): 6.5071
# Epoch: 1024  Loss: Train = [0.0460]  Acc: Val = [0.9639]  Time one epoch (s): 6.3680
# Epoch: 1025  Loss: Train = [0.0372]  Acc: Val = [0.9644]  Time one epoch (s): 6.3838
# Epoch: 1026  Loss: Train = [0.0446]  Acc: Val = [0.9647]  Time one epoch (s): 6.3910
# Epoch: 1027  Loss: Train = [0.0294]  Acc: Val = [0.9649]  Time one epoch (s): 6.4465
# Epoch: 1028  Loss: Train = [0.0391]  Acc: Val = [0.9651]  Time one epoch (s): 6.4041
# Epoch: 1029  Loss: Train = [0.0420]  Acc: Val = [0.9653]  Time one epoch (s): 6.3912
# Epoch: 1030  Loss: Train = [0.0348]  Acc: Val = [0.9651]  Time one epoch (s): 6.4412
# Epoch: 1031  Loss: Train = [0.0391]  Acc: Val = [0.9651]  Time one epoch (s): 6.4919
# Epoch: 1032  Loss: Train = [0.0522]  Acc: Val = [0.9652]  Time one epoch (s): 6.4783
# Epoch: 1033  Loss: Train = [0.0295]  Acc: Val = [0.9655]  Time one epoch (s): 6.5513
# Epoch: 1034  Loss: Train = [0.0407]  Acc: Val = [0.9645]  Time one epoch (s): 6.5200
# Epoch: 1035  Loss: Train = [0.0417]  Acc: Val = [0.9643]  Time one epoch (s): 6.4615
# Epoch: 1036  Loss: Train = [0.0378]  Acc: Val = [0.9645]  Time one epoch (s): 6.4291
# Epoch: 1037  Loss: Train = [0.0303]  Acc: Val = [0.9642]  Time one epoch (s): 6.5119
# Epoch: 1038  Loss: Train = [0.0261]  Acc: Val = [0.9643]  Time one epoch (s): 6.5631
# Epoch: 1039  Loss: Train = [0.0402]  Acc: Val = [0.9643]  Time one epoch (s): 6.5582
# Epoch: 1040  Loss: Train = [0.0469]  Acc: Val = [0.9641]  Time one epoch (s): 6.3182
# Epoch: 1041  Loss: Train = [0.0423]  Acc: Val = [0.9630]  Time one epoch (s): 6.4070
# Epoch: 1042  Loss: Train = [0.0458]  Acc: Val = [0.9625]  Time one epoch (s): 6.4569
# Epoch: 1043  Loss: Train = [0.0573]  Acc: Val = [0.9629]  Time one epoch (s): 6.4567
# Epoch: 1044  Loss: Train = [0.0345]  Acc: Val = [0.9630]  Time one epoch (s): 6.4207
# Epoch: 1045  Loss: Train = [0.0396]  Acc: Val = [0.9629]  Time one epoch (s): 6.4300
# Epoch: 1046  Loss: Train = [0.0368]  Acc: Val = [0.9634]  Time one epoch (s): 6.4755
# Epoch: 1047  Loss: Train = [0.0408]  Acc: Val = [0.9640]  Time one epoch (s): 6.4672
# Epoch: 1048  Loss: Train = [0.0467]  Acc: Val = [0.9645]  Time one epoch (s): 6.2765
# Epoch: 1049  Loss: Train = [0.0482]  Acc: Val = [0.9641]  Time one epoch (s): 6.2845
# Epoch: 1050  Loss: Train = [0.0389]  Acc: Val = [0.9641]  Time one epoch (s): 6.2528
# Epoch: 1051  Loss: Train = [0.0329]  Acc: Val = [0.9639]  Time one epoch (s): 6.3416
# Epoch: 1052  Loss: Train = [0.0284]  Acc: Val = [0.9635]  Time one epoch (s): 6.3670
# Epoch: 1053  Loss: Train = [0.0390]  Acc: Val = [0.9639]  Time one epoch (s): 6.3415
# Epoch: 1054  Loss: Train = [0.0294]  Acc: Val = [0.9637]  Time one epoch (s): 6.3839
# Epoch: 1055  Loss: Train = [0.0488]  Acc: Val = [0.9636]  Time one epoch (s): 6.4933
# Epoch: 1056  Loss: Train = [0.0455]  Acc: Val = [0.9637]  Time one epoch (s): 6.4044
# Epoch: 1057  Loss: Train = [0.0322]  Acc: Val = [0.9637]  Time one epoch (s): 6.4277
# Epoch: 1058  Loss: Train = [0.0436]  Acc: Val = [0.9636]  Time one epoch (s): 6.4356
# Epoch: 1059  Loss: Train = [0.0423]  Acc: Val = [0.9633]  Time one epoch (s): 6.3673
# Epoch: 1060  Loss: Train = [0.0646]  Acc: Val = [0.9640]  Time one epoch (s): 6.4062
# Epoch: 1061  Loss: Train = [0.0297]  Acc: Val = [0.9642]  Time one epoch (s): 6.4524
# Epoch: 1062  Loss: Train = [0.0459]  Acc: Val = [0.9637]  Time one epoch (s): 6.4023
# Epoch: 1063  Loss: Train = [0.0381]  Acc: Val = [0.9639]  Time one epoch (s): 6.4146
# Epoch: 1064  Loss: Train = [0.0507]  Acc: Val = [0.9636]  Time one epoch (s): 6.4589
# Epoch: 1065  Loss: Train = [0.0398]  Acc: Val = [0.9636]  Time one epoch (s): 6.3835
# Epoch: 1066  Loss: Train = [0.0388]  Acc: Val = [0.9632]  Time one epoch (s): 6.3809
# Epoch: 1067  Loss: Train = [0.0413]  Acc: Val = [0.9628]  Time one epoch (s): 6.4722
# Epoch: 1068  Loss: Train = [0.0399]  Acc: Val = [0.9631]  Time one epoch (s): 6.3603
# Epoch: 1069  Loss: Train = [0.0414]  Acc: Val = [0.9630]  Time one epoch (s): 6.3436
# Epoch: 1070  Loss: Train = [0.0289]  Acc: Val = [0.9631]  Time one epoch (s): 6.4238
# Epoch: 1071  Loss: Train = [0.0462]  Acc: Val = [0.9619]  Time one epoch (s): 6.5069
# Epoch: 1072  Loss: Train = [0.0442]  Acc: Val = [0.9615]  Time one epoch (s): 6.3947
# Epoch: 1073  Loss: Train = [0.0254]  Acc: Val = [0.9616]  Time one epoch (s): 6.4158
# Epoch: 1074  Loss: Train = [0.0418]  Acc: Val = [0.9620]  Time one epoch (s): 6.4109
# Epoch: 1075  Loss: Train = [0.0289]  Acc: Val = [0.9621]  Time one epoch (s): 6.4630
# Epoch: 1076  Loss: Train = [0.0407]  Acc: Val = [0.9625]  Time one epoch (s): 6.4165
# Epoch: 1077  Loss: Train = [0.0320]  Acc: Val = [0.9632]  Time one epoch (s): 6.3993
# Epoch: 1078  Loss: Train = [0.0314]  Acc: Val = [0.9634]  Time one epoch (s): 6.3851
# Epoch: 1079  Loss: Train = [0.0331]  Acc: Val = [0.9638]  Time one epoch (s): 6.4433
# Epoch: 1080  Loss: Train = [0.0357]  Acc: Val = [0.9635]  Time one epoch (s): 6.4208
# Epoch: 1081  Loss: Train = [0.0464]  Acc: Val = [0.9628]  Time one epoch (s): 6.3907
# Epoch: 1082  Loss: Train = [0.0273]  Acc: Val = [0.9634]  Time one epoch (s): 6.3352
# Epoch: 1083  Loss: Train = [0.0322]  Acc: Val = [0.9636]  Time one epoch (s): 6.3938
# Epoch: 1084  Loss: Train = [0.0319]  Acc: Val = [0.9631]  Time one epoch (s): 6.3864
# Epoch: 1085  Loss: Train = [0.0307]  Acc: Val = [0.9629]  Time one epoch (s): 6.4490
# Epoch: 1086  Loss: Train = [0.0528]  Acc: Val = [0.9628]  Time one epoch (s): 6.4443
# Epoch: 1087  Loss: Train = [0.0357]  Acc: Val = [0.9632]  Time one epoch (s): 6.3611
# Epoch: 1088  Loss: Train = [0.0309]  Acc: Val = [0.9631]  Time one epoch (s): 6.4110
# Epoch: 1089  Loss: Train = [0.0426]  Acc: Val = [0.9626]  Time one epoch (s): 6.3693
# Epoch: 1090  Loss: Train = [0.0323]  Acc: Val = [0.9619]  Time one epoch (s): 6.3714
# Epoch: 1091  Loss: Train = [0.0415]  Acc: Val = [0.9619]  Time one epoch (s): 6.4564
# Epoch: 1092  Loss: Train = [0.0335]  Acc: Val = [0.9620]  Time one epoch (s): 6.4005
# Epoch: 1093  Loss: Train = [0.0330]  Acc: Val = [0.9621]  Time one epoch (s): 6.3484
# Epoch: 1094  Loss: Train = [0.0375]  Acc: Val = [0.9624]  Time one epoch (s): 6.3750
# Epoch: 1095  Loss: Train = [0.0321]  Acc: Val = [0.9630]  Time one epoch (s): 6.4385
# Epoch: 1096  Loss: Train = [0.0472]  Acc: Val = [0.9637]  Time one epoch (s): 6.4217
# Epoch: 1097  Loss: Train = [0.0389]  Acc: Val = [0.9641]  Time one epoch (s): 6.4255
# Epoch: 1098  Loss: Train = [0.0243]  Acc: Val = [0.9643]  Time one epoch (s): 6.4270
# Epoch: 1099  Loss: Train = [0.0396]  Acc: Val = [0.9639]  Time one epoch (s): 6.4838
# Epoch: 1100  Loss: Train = [0.0405]  Acc: Val = [0.9643]  Time one epoch (s): 6.3896
# Epoch: 1101  Loss: Train = [0.0314]  Acc: Val = [0.9643]  Time one epoch (s): 6.3902
# Epoch: 1102  Loss: Train = [0.0404]  Acc: Val = [0.9650]  Time one epoch (s): 6.2805
# Epoch: 1103  Loss: Train = [0.0388]  Acc: Val = [0.9654]  Time one epoch (s): 6.3359
# Epoch: 1104  Loss: Train = [0.0348]  Acc: Val = [0.9647]  Time one epoch (s): 6.2184
# Epoch: 1105  Loss: Train = [0.0365]  Acc: Val = [0.9650]  Time one epoch (s): 6.1908
# Epoch: 1106  Loss: Train = [0.0448]  Acc: Val = [0.9655]  Time one epoch (s): 6.2001
# Epoch: 1107  Loss: Train = [0.0334]  Acc: Val = [0.9651]  Time one epoch (s): 6.2803
# Epoch: 1108  Loss: Train = [0.0282]  Acc: Val = [0.9651]  Time one epoch (s): 6.2714
